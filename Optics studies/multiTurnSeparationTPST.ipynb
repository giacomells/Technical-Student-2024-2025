# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats

import xtrack as xt
import xpart as xp
import xplt
# Out:
# /Users/matteogiacomelli/miniforge3/envs/xsuite_env/lib/python3.11/site-packages/xplt/hooks.py:31: RuntimeWarning: Failed to register formatters with pint: No module named 'pint'
#   warnings.warn(f"Failed to register formatters with pint: {e}", RuntimeWarning)

# %%
import pickle
import typing as t

import matplotlib.pyplot as plt
import numpy as np
import requests
import xobjects as xo
import xpart as xp
import xtrack as xt
import xcoll as xc
from cpymad.madx import Madx

# %matplotlib widget

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import minimize
import itertools

import re
import os
import pickle
from cpymad.madx import Madx
import distutils

import warnings
from IPython.display import display, HTML, Markdown, clear_output

display(HTML("<style>.rendered_html { font-size: 17px; }</style>"))
display(HTML("<style>.container { width:90% !important; }</style>"))

def printmd(string):
    display(Markdown(string))
# warnings.filterwarnings('ignore')



plt.ion()

p = 400.0  # beam momentum (GeV/c)
momentum = p  # beam momentum (GeV/c)
Brho = p * 3.3356  # beam rigidity ???

N_EX = 10e-6
N_EY = 5e-6
# Out:
# <style>.rendered_html { font-size: 17px; }</style>
# <style>.container { width:90% !important; }</style>

# %%
# Proton mass in GeV/c^2
proton_mass_GeV = xt.PROTON_MASS_EV * 1e-9

# Beam energy in GeV
beam_energy_GeV = 400

# Compute gamma
gamma = beam_energy_GeV / proton_mass_GeV
print(f"Gamma: {gamma}")
# Out:
# Gamma: 426.31556991578066

# %%
EX = N_EX / gamma
EY = N_EY / gamma
print(f"EX: {EX}")
# Out:
# EX: 2.3456802204000003e-08

# %%
deltaP_P = 1.5e-3
print(f"deltaP_P: {deltaP_P}")
# Out:
# deltaP_P: 0.0015

# %%
# TECA DEFINITION

TECA = xc.EverestCrystal(
    length=2e-3, 
    material=xc.materials.SiliconCrystal, 
    bending_angle = 174e-6 ,
    side="left",
    lattice="strip",
    jaw = - 52.4e-3,
    tilt = - 1.23e-3,
    width = 1.8e-3,
    height = 50e-3
    )

TECS = xc.EverestCrystal(
    length=2e-3, 
    material=xc.materials.SiliconCrystal, 
    bending_angle = 174e-6 ,
    side="left",
    lattice="strip",
    jaw = -0.0315,
    tilt = 10e-6,
    width = 2e-3,
    height = 50e-3
    )

# Given values
x_teca = TECA.jaw  
delta_x_teca_prime = TECA.tilt + TECA.bending_angle
# Out:
# Warning: Setting a negative tilt does not preserve the hierarchy, as the crystal tightens towards the beam.

# %%
def match_tunes(line, qx, qy):
    # Extraction tunes
    opt = line.match(solve=False,
                     method='4d',
        vary=[
            xt.VaryList(['kqf', 'kqd'], step=1e-7),   # Varying quadrupole focal strengths
            xt.VaryList(['qph_setvalue', 'qpv_setvalue'], step=1e-4),   # Varying phase values
        ],
        targets=[
            xt.TargetSet(qx=qx, qy=qy, tol=1e-5),# Desired target tunes
            #xt.TargetSet(dqx=-1 * qx, dqy=0.47 * qy, tol=1e-3),   # Desired target chromaticities
        ])
    return opt

# %%
def match_chromaticity(line, qx, qy):
    # Extraction tunes
    opt = line.match(solve=False,
                     method='4d',
        vary=[
            xt.VaryList(['klsfa', 'klsda', 'klsdb', 'klsfb'], step=1e-7),   # Varying setupoles strengths ,  klsfa, klsda, klsfb, klsdb????
        ],
        targets=[
            xt.TargetSet(dqx=-1 * int(qx), dqy = 0.47 * int(qy), tol=1e-3),   # Desired target chromaticities
        ])
    return opt

# %% [markdown]
# ## Uploading the line from Q22

# %%
from elements import install_septa

line = xt.Line.from_json("./database/lhc_q22.json")


# REFERENCE PARTICLE
line.particle_ref = xt.Particles(p0c=400e9, mass0=xt.PROTON_MASS_EV)

# INSERTING MARKERS
line.insert_element(name='zs21633.entry.p1mm', element=xt.Marker(), at_s=line.get_table()['s', 'ap.up.zs21633']+1e-3)
line.insert_element("tpst.21760_entry", xt.Marker(), at_s = 1712.2203)
line.insert_element("TECA.entry", xt.Marker(), at_s = 4020.8939)
#line.insert_element("TECS.everest_crystal", TECS, at_s = line.get_table()['s', 'tecs.21602'] )

line.insert_element("tcsm.51932.", xt.Marker(), at_s = 5219.6766)

teca_entry_s = line.get_table()['s', 'TECA.entry']


septa_names_with_apertures = install_septa(line, install_zs=False)
line.cycle("TECA.entry", inplace=True)
# Out:
# Loading line from dict:   0%|          | 0/4598 [00:00<?, ?it/s]
# Done loading line from dict.
# Slicing line:   0%|          | 0/4598 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/4601 [00:00<?, ?it/s]
# <Line  at 4869476176>

# %% [markdown]
# ### Computing twiss parameters and other properties from this optics

# %%
tw_init = line.twiss(method='4d')
print(tw_init.qx)
print(tw_init.qy)

tw0 = tw_init.to_pandas()
tw0.index = tw0.name
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# 22.13000000002023
# 22.180000000010537

# %%
betx_teca = tw0.loc['TECA.entry'].betx
dx_teca = tw0.loc['TECA.entry'].dx

# COMPUTING THE BEAM SIZE 
tw0['sx_mm'] = np.sqrt(tw0['betx'] * EX + (tw0['dx'] * deltaP_P)**2) * 1e3
tw0['sy_mm'] = np.sqrt(tw0['bety'] * EY + (tw0['dy'] * deltaP_P)**2) * 1e3
    
B_term0 = betx_teca * EX
D_term0 = (dx_teca * deltaP_P)**2
ratio0 = D_term0 / B_term0

print(f'D term / B term = {ratio0:.2f}')
print(f"sigma_x max = {tw0.sx_mm.max()} mm")
print(f"sigma_y max = {tw0.sy_mm.max()} mm")
# Out:
# D term / B term = 3.31
# sigma_x max = 10.468444858830788 mm
# sigma_y max = 1.1036200160887548 mm

# %%
mu_x_teca = tw0.loc['TECA.entry'].mux
mu_x_tpst = tw0.loc['tpst.21760_entry'].mux
mu_x_tcsm = tw0.loc['tcsm.51932.'].mux

phaseAdvanceTecaTpst = mu_x_tpst - mu_x_teca
phaseAdvanceTecaTcsm = mu_x_tcsm - mu_x_teca
phaseAdvanceTpstTcsm = mu_x_tcsm - mu_x_tpst

print(f"Phase advance Teca - Tpst: {phaseAdvanceTecaTpst:.2f}")
print(f"Phase advance Teca - Tcsm: {phaseAdvanceTecaTcsm:.2f}")
print(f"Phase advance Tpst - Tcsm: {phaseAdvanceTpstTcsm:.2f}")
# Out:
# Phase advance Teca - Tpst: 14.74
# Phase advance Teca - Tcsm: 3.83
# Phase advance Tpst - Tcsm: -10.91

# %%
# Get the positions of the TECA and COLLIMATORS markers
teca_position = line.get_table()['s', 'TECA.entry']
tpst_position = line.get_table()['s', 'tpst.21760_entry']
tcsm_position = line.get_table()['s', 'tcsm.51932.']

# %% [markdown]
# ## Choosing the tune

# %%
tune = 22.99

# %% [markdown]
# # Switching to desired tune and modifying the apertures

# %%
optTune = match_tunes(line, tune, tune + 0.05)
optChromaticity = match_chromaticity(line, tune, tune + 0.05)

optTune.step(10)
optTune.target_status()
optTune.vary_status()

# CHanging the chromaticity afterwards
optChromaticity.step(10)

optChromaticity.target_status()
optChromaticity.vary_status()
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 12.16
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2161e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2164e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2013e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1706e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.3188e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 6.7830e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 19 penalty = 8.6243e-07
# Optimize - end penalty:  8.62433e-07
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 8.6243e-07
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    qx     True   8.62346e-08         22.99         22.99 'qx', val=22.99, tol=1e-05, weight=10
# 1  ON    qy     True   1.22724e-09         23.04         23.04 'qy', val=23.04, tol=1e-05, weight=10
# Vary status:
# id state tag met name         lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  kqf          None            0.0129904 None            0.0125751         1e-07             1
# 1  ON        OK  kqd          None           -0.0129933 None           -0.0125777         1e-07             1
# 2  ON        OK  qph_setvalue None          1.48368e-14 None                    0        0.0001             1
# 3  ON        OK  qpv_setvalue None          5.86856e-14 None                    0        0.0001             1
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 24.09
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1284e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4107e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3917e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3967e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4111e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 25 penalty = 2.3670e-05
# Optimize - end penalty:  2.36701e-05
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 2.3670e-05
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    dqx    True  -2.36701e-05           -22           -22 'dqx', val=-22, tol=0.001, weight=1
# 1  ON    dqy    True  -1.21571e-09         10.81         10.81 'dqy', val=10.81, tol=0.001, weight=1
# Vary status:
# id state tag met name  lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  klsfa None             0.013625 None            0.0507061         1e-07             1
# 1  ON        OK  klsda None            0.0372456 None            0.0553165         1e-07             1
# 2  ON        OK  klsdb None            -0.197003 None            -0.167456         1e-07             1
# 3  ON        OK  klsfb None            0.0193201 None            0.0586313         1e-07             1

# %% [markdown]
# Changing the apertures of the elements to let the beam pass

# %%
# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitEllipse
    if isinstance(element, xt.LimitEllipse):
        print(f"Element Name: {element_name}, Element: {element}")
        element.a = 1
        element.b = 1
        
# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitRect
    if isinstance(element, xt.LimitRect):
        print(f"Element Name: {element_name}, Element: {element}")
        element.min_x = -1
        element.max_x = 1
# Out:
# Element Name: qe.11402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qd.11710_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qf.11810_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.21610_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qfa.21810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.30202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.30602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.31402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.up.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.do.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.up.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: ap.do.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: qfa.41810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.50202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.51402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.do.qf51410_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.up.mbb51470_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51610_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: ap.do.mdhw.51637_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcxhw.51651_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51652_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: mdvw.51694_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: mdvw.51696_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: xrp.51791_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcpc.51794_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51795_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51797_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51799_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51810_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: btv.51858_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.do.qd.51910_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: xrp.51993_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51997_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51998_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qecd.53402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60302_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60502_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.61810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: mdhw.11732_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11737_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.
min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst61794_aper, Element: LimitRect(min_x=-0.054, max_x=0.054, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: qspl.61809_aper, Element: LimitRect(min_x=-0.108, max_x=0.108, min_y=-0.029, max_y=0.029, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61832_aper, Element: LimitRect(min_x=-0.058, max_x=0.058, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61832_aper, Element: LimitRect(min_x=-0.0571, max_x=0.0571, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61837_aper, Element: LimitRect(min_x=-0.0574, max_x=0.0574, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61837_aper, Element: LimitRect(min_x=-0.0594, max_x=0.0594, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61852_aper, Element: LimitRect(min_x=-0.0609, max_x=0.0609, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61852_aper, Element: LimitRect(min_x=-0.0658, max_x=0.0658, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61857_aper, Element: LimitRect(min_x=-0.0685, max_x=0.0685, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61857_aper, Element: LimitRect(min_x=-0.0764, max_x=0.0764, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61872_aper, Element: LimitRect(min_x=-0.0802, max_x=0.0802, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61872_aper, Element: LimitRect(min_x=-0.091, max_x=0.091, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: tt20.extraction, Element: LimitRect(min_x=-70, max_x=0.15, min_y=-1, max_y=1, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)

# %% [markdown]
# ### Changing the tpst blade position to block the non-channeled particles

# %%
element_name = 'tpst.21760_entry.sep'
element = line[element_name]

print(f"Element Name: {element_name}")
print(f"Type: {type(element)}")
print(f"Length: {element.length}")
print(f"Blade Position: {element.interaction_process.blade_position}")
print(f"Thickness: {element.interaction_process.thickness}")
print(f"Kick: {element.interaction_process.kick}")


# MOVING THE BLADE UP OR DOWN
element.interaction_process.blade_position = 0.03
print(f"Updated Blade Position: {element.interaction_process.blade_position}")
# Out:
# Element Name: tpst.21760_entry.sep
# Type: <class 'xdeps.madxutils.View'>
# Length: 0.0
# Blade Position: 0.0394
# Thickness: 0.0045
# Kick: 0
# Updated Blade Position: 0.03

# %% [markdown]
# # Tracking channeled particles

# %% [markdown]
# The particles are initialised with a px equal to the tilt of the crystal plus it's bending angle

# %%
tw = line.twiss(method='4d')

line.discard_tracker()
line.insert_element("TECS.everest_crystal", TECS, at_s = line.get_table()['s', 'tecs.21602'] )
line.build_tracker()

# Initialize a single particle at TECA location
particles = line.build_particles(
        method='4d',
        x = TECA.jaw,
        px = TECA.tilt + TECA.bending_angle,                    # THE BENDING ANGLE INDICATES THAT THE PARTICLE IS CHANNELED
        y = 0,
        py = 0,
        zeta = 0,
        delta = deltaP_P,
        mass0 = xt.PROTON_MASS_EV,
        p0c = 400e9
    )

# Track particles for N turns and store positions
num_turns = 1
line.track(
        particles,
        num_turns=num_turns,
        turn_by_turn_monitor="ONE_TURN_EBE",
    )
    

    # Check if the particle is lost during the tracking
if np.any(particles.state < 1):
    lost_turn = np.where(particles.state < 1)[0][0]
    print(f"Particle lost at turn {lost_turn}")
else:
    print("Particle not lost during the tracking")
    
    
# Plot the phase space at TECA location
plt.figure(figsize=(10, 6))
#plt.plot(line.record_last_track.x, line.record_last_track.px, 'o')
plt.plot(line.record_last_track.s[0], line.record_last_track.x[0], 'o')

#plt.xlabel('x [m]')
plt.xlabel('s [m]')

#plt.ylabel('px [rad]')
plt.ylabel('x [m]')

plt.title(f'Channeled particle trajectory from TECA to TPST, tune Q{tune}')
plt.grid(True)

# Draw a rectangle at the TPST entry location
tpst = plt.Rectangle((tpst_position, element.interaction_process.blade_position), 
                     width=2, height=element.interaction_process.thickness, 
                     color='grey', alpha=0.5, label='TPST Blade')
plt.gca().add_patch(tpst)

tecs_position = line.get_table()['s', 'TECS.everest_crystal']
tecs = plt.Rectangle((tecs_position, TECS.jaw), 
                     width=TECA.length, height=TECA.width, 
                     color='blue', alpha=0.5, label='TECS Blade')
plt.gca().add_patch(tecs)

plt.ylim(-1, 1)
plt.xlim(0, 7000)
#plt.ylim(-0.1, 0.1)
#plt.xlim(4520, 4620)

plt.axvline(x=tpst_position, color='r', linestyle='--', label='TPST location')
plt.axvline(x=tecs_position, color='r', linestyle='--', label='TECS location')


plt.legend()
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Slicing line:   0%|          | 0/4614 [00:00<?, ?it/s]
# Particle not lost during the tracking
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
recordChanneled = line.record_last_track
# Extract the s and x values from the record
s_valuesChanneled = recordChanneled.data.s
x_valuesChanneled = recordChanneled.data.x



# Find the index of the tpst location in the s_values array using np.isclose
tpst_index = np.where(np.isclose(s_valuesChanneled, tpst_position))[0][0]

# Get the x value at the tpst location
x_tpstChanneled = x_valuesChanneled[tpst_index]

print(f"x at TPST location: {x_tpstChanneled}")
# Out:
# x at TPST location: 0.023618020755747766

# %% [markdown]
# ## Tracking the non channeled particles

# %%
line = xt.Line.from_json("./database/lhc_q22.json")


# REFERENCE PARTICLE
line.particle_ref = xt.Particles(p0c=400e9, mass0=xt.PROTON_MASS_EV)

# INSERTING MARKERS
line.insert_element(name='zs21633.entry.p1mm', element=xt.Marker(), at_s=line.get_table()['s', 'ap.up.zs21633']+1e-3)
line.insert_element("tpst.21760_entry", xt.Marker(), at_s = 1712.2203)
line.insert_element("TECA.entry", xt.Marker(), at_s = 4020.8939)
#line.insert_element("TECS.everest_crystal", TECS, at_s = line.get_table()['s', 'tecs.21602'] )

line.insert_element("tcsm.51932.", xt.Marker(), at_s = 5219.6766)

teca_entry_s = line.get_table()['s', 'TECA.entry']


septa_names_with_apertures = install_septa(line, install_zs=False)
line.cycle("TECA.entry", inplace=True)

optTune = match_tunes(line, tune, tune + 0.05)
optChromaticity = match_chromaticity(line, tune, tune + 0.05)

# Optimisers for tune
optTune.step(10)
optTune.target_status()
optTune.vary_status()

# Optimisers for chromaticity
optChromaticity.step(10)
optChromaticity.target_status()
optChromaticity.vary_status() 



# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitEllipse
    if isinstance(element, xt.LimitEllipse):
        print(f"Element Name: {element_name}, Element: {element}")
        element.a = 1
        element.b = 1
        
# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitRect
    if isinstance(element, xt.LimitRect):
        print(f"Element Name: {element_name}, Element: {element}")
        element.min_x = -1
        element.max_x = 1
        
        
element_name = 'tpst.21760_entry.sep'
element = line[element_name]

print(f"Element Name: {element_name}")
print(f"Type: {type(element)}")
print(f"Length: {element.length}")
print(f"Blade Position: {element.interaction_process.blade_position}")
print(f"Thickness: {element.interaction_process.thickness}")
print(f"Kick: {element.interaction_process.kick}")


# MOVING THE BLADE UP OR DOWN
element.interaction_process.blade_position = 0.03
print(f"Updated Blade Position: {element.interaction_process.blade_position}")
# Out:
# Loading line from dict:   0%|          | 0/4598 [00:00<?, ?it/s]
# Done loading line from dict.
# Slicing line:   0%|          | 0/4598 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/4601 [00:00<?, ?it/s]
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 12.16
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2161e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2164e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2013e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1706e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.3188e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 6.7830e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 19 penalty = 8.6243e-07
# Optimize - end penalty:  8.62433e-07
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 8.6243e-07
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    qx     True   8.62346e-08         22.99         22.99 'qx', val=22.99, tol=1e-05, weight=10
# 1  ON    qy     True   1.22724e-09         23.04         23.04 'qy', val=23.04, tol=1e-05, weight=10
# Vary status:
# id state tag met name         lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  kqf          None            0.0129904 None            0.0125751         1e-07             1
# 1  ON        OK  kqd          None           -0.0129933 None           -0.0125777         1e-07             1
# 2  ON        OK  qph_setvalue None          1.48368e-14 None                    0        0.0001             1
# 3  ON        OK  qpv_setvalue None          5.86856e-14 None                    0        0.0001             1
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 24.09
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1284e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4107e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3917e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3967e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4111e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 25 penalty = 2.3670e-05
# Optimize - end penalty:  2.36701e-05
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 2.3670e-05
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    dqx    True  -2.36701e-05           -22           -22 'dqx', val=-22, tol=0.001, weight=1
# 1  ON    dqy    True  -1.21571e-09         10.81         10.81 'dqy', val=10.81, tol=0.001, weight=1
# Vary status:
# id state tag met name  lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  klsfa None             0.013625 None            0.0507061         1e-07             1
# 1  ON        OK  klsda None            0.0372456 None            0.0553165         1e-07             1
# 2  ON        OK  klsdb None            -0.197003 None            -0.167456         1e-07             1
# 3  ON        OK  klsfb None            0.0193201 None            0.0586313         1e-07             1
# Element Name: qe.11402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qd.11710_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qf.11810_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.21610_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qfa.21810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.30202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.30602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.31402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.up.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.do.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.up.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: ap.do.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: qfa.41810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.50202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.51402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.do.qf51410_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.up.mbb51470_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51610_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: ap.do.mdhw.51637_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcxhw.51651_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51652_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: mdvw.51694_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: mdvw.51696_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: xrp.51791_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcpc.51794_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51795_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51797_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51799_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51810_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: btv.51858_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.do.qd.51910_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: xrp.51993_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51997_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51998_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qecd.53402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60302_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60502_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.61810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: mdhw.11732_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11737_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11738_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11754_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21633_aper, Element: LimitRect(min_x=-0.068, max_x=0.068, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21633_aper, Element: LimitRect(min_x=-0.0633, max_x=0.0633, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21655_aper, Element: LimitRect(min_x=-0.0562, max_x=0.0562, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21655_aper, Element: LimitRect(min_x=-0.0516, max_x=0.0516, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21671_aper, Element: LimitRect(min_x=-0.0503, max_x=0.0503, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21671_aper, Element: LimitRect(min_x=-0.0457, max_x=0.0457, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21676_aper, Element: LimitRect(min_x=-0.0445, max_x=0.0445, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21676_aper, Element: LimitRect(min_x=-0.0398, max_x=0.0398, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21774_aper, Element: LimitRect(min_x=-0.0408, max_x=0.0408, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst21774_aper, Element: LimitRect(min_x=-0.042, max_x=0.042, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21779_aper, Element: LimitRect(min_x=-0.0424, max_x=0.0424, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst21779_aper, Element: LimitRect(min_x=-0.0436, max_x=0.0436, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21794_aper, Element: LimitRect(min_x=-0.044, max_x=0.044, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst
_sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: tpst.21760_entry.sep
# Type: <class 'xdeps.madxutils.View'>
# Length: 0.0
# Blade Position: 0.0394
# Thickness: 0.0045
# Kick: 0
# Updated Blade Position: 0.03

# %% [markdown]
# Creating the particles with a px equal to the tilt of the crystal (non channeled)

# %%
tw = line.twiss(method='4d')

line.discard_tracker()
line.insert_element("TECS.everest_crystal", TECS, at_s = line.get_table()['s', 'tecs.21602'] )
line.build_tracker()



# Initialize a single particle at TECA location
particles = line.build_particles(
        method='4d',
        x = TECA.jaw,
        px = TECA.tilt,                    # THE BENDING ANGLE INDICATES THAT THE PARTICLE IS CHANNELED
        y = 0,
        py = 0,
        zeta = 0,
        delta = deltaP_P,
        mass0 = xt.PROTON_MASS_EV,
        p0c = 400e9
    )

# Track particles for N turns and store positions
num_turns = 100
line.track(
        particles,
        num_turns=1,
        turn_by_turn_monitor="ONE_TURN_EBE",
    )
    
# Plot the phase space at TECA location
plt.figure(figsize=(10, 6))
#plt.plot(line.record_last_track.x, line.record_last_track.px, 'o')
plt.plot(line.record_last_track.s[0], line.record_last_track.x[0], 'o')

#plt.xlabel('x [m]')
plt.xlabel('s [m]')

#plt.ylabel('px [rad]')
plt.ylabel('x [m]')
plt.ylim(-1, 1)
plt.xlim(0, 7000)
#plt.ylim(-0.1, 0.1)
#plt.xlim(4520, 4620)

plt.title(f'Non-Channeled particle trajectory from TECA to TPST, tune Q{tune}')
plt.grid(True)

# Draw a rectangle at the TPST entry location
tpst = plt.Rectangle((tpst_position, element.interaction_process.blade_position), 
                     width=2, height=element.interaction_process.thickness, 
                     color='grey', alpha=0.5, label='TPST Blade')
plt.gca().add_patch(tpst)


tecs_position = line.get_table()['s', 'TECS.everest_crystal']
tecs = plt.Rectangle((tecs_position, TECS.jaw), 
                     width=TECA.length, height=TECA.width, 
                     color='blue', alpha=0.5, label='TECS Blade')
plt.gca().add_patch(tecs)

plt.axvline(x=tpst_position, color='r', linestyle='--', label='TPST location')
plt.axvline(x=tecs_position, color='r', linestyle='--', label='TECS location')

plt.legend()
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Slicing line:   0%|          | 0/4614 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
recordNONChanneled = line.record_last_track
# Extract the s and x values from the record
s_valuesNONChanneled = recordNONChanneled.data.s
x_valuesNONChanneled = recordNONChanneled.data.x


# Find the index of the tpst location in the s_values array using np.isclose
tpst_index = np.where(np.isclose(s_valuesNONChanneled, tpst_position))[0][0]

# Get the x value at the tpst location
x_tpstNONChanneled = x_valuesNONChanneled[tpst_index]

print(f"x at TPST location: {x_tpstNONChanneled}")
# Out:
# x at TPST location: 0.01417565536123311

# %% [markdown]
# ## Double check the aperture given by the channeling at the TPST

# %%
from IPython.display import display, Math

print(f"TECA position: {teca_position}")
print(f"TPST position: {tpst_position}")
print(f"Horizontal osition at tpst for channeled particles: {x_tpstChanneled}")
print(f"Horizontal osition at tpst for non-channeled particles: {x_tpstNONChanneled}")


display(Math(r"\Delta x = {:.2f} \, \text{{mm}}".format((x_tpstChanneled - x_tpstNONChanneled) * 1e3)))
# Out:
# TECA position: 0.0
# TPST position: 4602.830199999884
# Horizontal osition at tpst for channeled particles: 0.023618020755747766
# Horizontal osition at tpst for non-channeled particles: 0.01417565536123311
# $\displaystyle \Delta x = 9.44 \, \text{mm}$

# %% [markdown]
# # Multiturn study for same optics

# %%
line = xt.Line.from_json("./database/lhc_q22.json")


# REFERENCE PARTICLE
line.particle_ref = xt.Particles(p0c=400e9, mass0=xt.PROTON_MASS_EV)



line.discard_tracker()
# INSERTING MARKERS
line.insert_element(name='zs21633.entry.p1mm', element=xt.Marker(), at_s=line.get_table()['s', 'ap.up.zs21633']+1e-3)
line.insert_element("tpst.21760_entry", xt.Marker(), at_s = 1712.2203)
line.insert_element("TECA.entry", xt.Marker(), at_s = 4020.8939)
#line.insert_element("TECS.everest_crystal", TECS, at_s = line.get_table()['s', 'tecs.21602'] )
line.insert_element("tcsm.51932.", xt.Marker(), at_s = 5219.6766)

teca_entry_s = line.get_table()['s', 'TECA.entry']


septa_names_with_apertures = install_septa(line, install_zs=False)
line.cycle("TECA.entry", inplace=True)

optTune = match_tunes(line, tune, tune + 0.05)
optChromaticity = match_chromaticity(line, tune, tune + 0.05)

# Optimisers for tune
optTune.step(10)
optTune.target_status()
optTune.vary_status()

# Optimisers for chromaticity
optChromaticity.step(10)
optChromaticity.target_status()
optChromaticity.vary_status() 




# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitEllipse
    if isinstance(element, xt.LimitEllipse):
        print(f"Element Name: {element_name}, Element: {element}")
        element.a = 1
        element.b = 1
        
# Iterate through all elements in the line
for element_name, element in line.element_dict.items():
    # Check if the element is of type LimitRect
    if isinstance(element, xt.LimitRect):
        print(f"Element Name: {element_name}, Element: {element}")
        element.min_x = -1
        element.max_x = 1
        
        
element_name = 'tpst.21760_entry.sep'
element = line[element_name]

print(f"Element Name: {element_name}")
print(f"Type: {type(element)}")
print(f"Length: {element.length}")
print(f"Blade Position: {element.interaction_process.blade_position}")
print(f"Thickness: {element.interaction_process.thickness}")
print(f"Kick: {element.interaction_process.kick}")


# MOVING THE BLADE UP OR DOWN
element.interaction_process.blade_position = 0.03
print(f"Updated Blade Position: {element.interaction_process.blade_position}")
# Out:
# Loading line from dict:   0%|          | 0/4598 [00:00<?, ?it/s]
# Done loading line from dict.
# Slicing line:   0%|          | 0/4598 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/4601 [00:00<?, ?it/s]
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 12.16
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2161e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2164e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2162e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 1.2013e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1706e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1846e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.3188e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 6.7830e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 5.5175e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 19 penalty = 8.6243e-07
# Optimize - end penalty:  8.62433e-07
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 8.6243e-07
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    qx     True   8.62346e-08         22.99         22.99 'qx', val=22.99, tol=1e-05, weight=10
# 1  ON    qy     True   1.22724e-09         23.04         23.04 'qy', val=23.04, tol=1e-05, weight=10
# Vary status:
# id state tag met name         lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  kqf          None            0.0129904 None            0.0125751         1e-07             1
# 1  ON        OK  kqd          None           -0.0129933 None           -0.0125777         1e-07             1
# 2  ON        OK  qph_setvalue None          1.48368e-14 None                    0        0.0001             1
# 3  ON        OK  qpv_setvalue None          5.86856e-14 None                    0        0.0001             1
#
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Optimize - start penalty: 24.09
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 2.4089e+01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7573e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements. = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7572e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 8.7571e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1283e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1284e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.1285e-01
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3899e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4107e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3917e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.3967e-03
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.y = 1.4111e-03
# In the twiss computation collective elements are replaced by drifts
# Matching: model call n. 25 penalty = 2.3670e-05
# Optimize - end penalty:  2.36701e-05
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# Target status:               nalty = 2.3670e-05
# id state tag tol_met       residue   current_val    target_val description
# 0  ON    dqx    True  -2.36701e-05           -22           -22 'dqx', val=-22, tol=0.001, weight=1
# 1  ON    dqy    True  -1.21571e-09         10.81         10.81 'dqy', val=10.81, tol=0.001, weight=1
# Vary status:
# id state tag met name  lower_limit   current_val upper_limit val_at_iter_0          step        weight
# 0  ON        OK  klsfa None             0.013625 None            0.0507061         1e-07             1
# 1  ON        OK  klsda None            0.0372456 None            0.0553165         1e-07             1
# 2  ON        OK  klsdb None            -0.197003 None            -0.167456         1e-07             1
# 3  ON        OK  klsfb None            0.0193201 None            0.0586313         1e-07             1
# Element Name: qe.11402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qd.11710_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qf.11810_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.21610_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qfa.21810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.30202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.30602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qecd.31402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.up.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.do.vvsb_aper, Element: LimitEllipse(a=0.156, b=0.156)
# Element Name: ap.up.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: ap.do.coldex_aper, Element: LimitEllipse(a=0.0335, b=0.0335)
# Element Name: qfa.41810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: qe.50202_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.51402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: ap.do.qf51410_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.up.mbb51470_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51610_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: ap.do.mdhw.51637_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcxhw.51651_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51652_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: mdvw.51694_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: mdvw.51696_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: xrp.51791_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tcpc.51794_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51795_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51797_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tecs.51799_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qfa.51810_aper, Element: LimitEllipse(a=0.0755, b=0.0455)
# Element Name: btv.51858_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: ap.do.qd.51910_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: xrp.51993_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tqcd.51997_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: tacw.51998_aper, Element: LimitEllipse(a=0.078, b=0.078)
# Element Name: qecd.53402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60302_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60402_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qe.60502_aper, Element: LimitEllipse(a=0.0415, b=0.0415)
# Element Name: qe.60602_aper, Element: LimitEllipse(a=0.076, b=0.0192)
# Element Name: qfa.61810_aper, Element: LimitEllipse(a=0.106, b=0.0203)
# Element Name: mdhw.11732_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11737_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11738_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: mdhw.11754_aper, Element: LimitRect(min_x=-0.076, max_x=0.076, min_y=-0.0176, max_y=0.0176, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21633_aper, Element: LimitRect(min_x=-0.068, max_x=0.068, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21633_aper, Element: LimitRect(min_x=-0.0633, max_x=0.0633, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21655_aper, Element: LimitRect(min_x=-0.0562, max_x=0.0562, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21655_aper, Element: LimitRect(min_x=-0.0516, max_x=0.0516, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21671_aper, Element: LimitRect(min_x=-0.0503, max_x=0.0503, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21671_aper, Element: LimitRect(min_x=-0.0457, max_x=0.0457, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.zs21676_aper, Element: LimitRect(min_x=-0.0445, max_x=0.0445, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.zs21676_aper, Element: LimitRect(min_x=-0.0398, max_x=0.0398, min_y=-0.023, max_y=0.023, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21774_aper, Element: LimitRect(min_x=-0.0408, max_x=0.0408, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst21774_aper, Element: LimitRect(min_x=-0.042, max_x=0.042, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21779_aper, Element: LimitRect(min_x=-0.0424, max_x=0.0424, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mst21779_aper, Element: LimitRect(min_x=-0.0436, max_x=0.0436, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mst21794_aper, Element: LimitRect(min_x=-0.044, max_x=0.044, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.m
min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61852_aper, Element: LimitRect(min_x=-0.0658, max_x=0.0658, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61857_aper, Element: LimitRect(min_x=-0.0685, max_x=0.0685, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61857_aper, Element: LimitRect(min_x=-0.0764, max_x=0.0764, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.up.mse61872_aper, Element: LimitRect(min_x=-0.0802, max_x=0.0802, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: ap.do.mse61872_aper, Element: LimitRect(min_x=-0.091, max_x=0.091, min_y=-0.078, max_y=0.078, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: tt20.extraction, Element: LimitRect(min_x=-70, max_x=0.15, min_y=-1, max_y=1, _sin_rot_s=-999, _cos_rot_s=-999, _shift_x=0, _shift_y=0, _shift_s=0)
# Element Name: tpst.21760_entry.sep
# Type: <class 'xdeps.madxutils.View'>
# Length: 0.0
# Blade Position: 0.0394
# Thickness: 0.0045
# Kick: 0
# Updated Blade Position: 0.03

# %%
tw_table = line.twiss(method='4d', x = TECA.jaw, px = TECA.tilt)


tw = line.twiss(method='4d', x = TECA.jaw, px = TECA.tilt)
tw = tw.to_pandas()
tw.index = tw.name
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts

# %%
# Initialize an empty DataFrame to store Twiss parameters
twiss_df = pd.DataFrame()

# %%
print([0,10])
# Out:
# [0, 10]

# %%
# Loop over the range of tunes
for N in range(11):
    
        
    beta_x_at_teca = tw.loc['TECA.entry'].betx
    beta_tpst = tw.loc['tpst.21760_entry'].betx
    alpha_teca = tw.loc['TECA.entry'].alfx                 #ALPHA X AT TECA
    
    
    # Get the phase advances at the positions of the TECA and TPST markers
    mu_x_teca = tw.loc['TECA.entry'].mux
    mu_x_tpst = tw.loc['tpst.21760_entry'].mux
    mu_x_tcsm = tw.loc['tcsm.51932.'].mux

    # Calculate the phase advance between the TECA and TPST markers
    delta_mu_xtpst = ((mu_x_tpst - mu_x_teca)) * 2 * np.pi
    # Calculate the phase advance between the TECA and TCMS markers
    delta_mu_x_tcsm = ((mu_x_tcsm - mu_x_teca)) * 2 * np.pi
    # Calculate the phase advance between the TPST and TCMS markers
    delta_mu_TCSM_TPST = ((mu_x_tcsm - mu_x_tpst)) * 2 * np.pi
    
    # RETREIVING THE EVOLUTION MATRIX FROM TECA FROM TWISS TABLE
    # Define number of turns (adjust N as needed)
    #N = number of turns
    # Compute the transfer matrix for one full turn from TECA.entry to itself
    full_turn_matrix = tw_table.get_R_matrix(start='TECA.entry', end='_end_point')
    # Compute the full turn matrix exponentiated to N turns
    full_turn_matrix_N = np.linalg.matrix_power(full_turn_matrix, N)
    # Compute the transport matrix from TECA to TPST
    Half_turn_matrix = tw_table.get_R_matrix(start='TECA.entry', end='tpst.21760_entry')
    # Compute the overall transport matrix for N turns plus transport to TPST
    multi_turn_to_tpst = full_turn_matrix_N @ Half_turn_matrix

    phaseAdvanceTecaTpst = delta_mu_xtpst  + N * tune * 2 * np.pi # phase advance between TECA and TPST for more than half a turn (N)

    # tw['delta_x'] = multi_turn_to_tpst[0, 1] * TECA.bending_angle
    tw['delta_x'] = np.sqrt(betx_teca * beta_tpst) * np.sin(phaseAdvanceTecaTpst) * TECA.bending_angle
    tw['xcol'] = multi_turn_to_tpst[0, 0] * (TECA.jaw + TECA.width / 2) + multi_turn_to_tpst[0, 1] * TECA.tilt
     # THIS WILL CHANGE WHEN WE SET THE BUMP TO GET THE BEAM CLOSE TO THE CRYSTAL
    


    
    
                                                                    # x AT TPST 
    #####################################################################
    #x_NONchanneledTPST = np.sqrt(beta_tpst/beta_x_at_teca) * (np.cos(delta_mu_xtpst) + alpha_teca * np.sin(delta_mu_xtpst)) * (TECA.jaw + TECA.width) + np.sqrt(beta_tpst*beta_x_at_teca) *  np.sin(delta_mu_xtpst) * TECA.tilt   # ANALITIC FORMULAE FOR PERIODIC LATTICES
    x_NONchanneledTPST = tw.loc['tpst.21760_entry'].xcol
    
                                                                            # DIFFERENCE BETWEEN CHANNELED AND NON CHANNELED PARTICLES POSITION AT THE COLLIMATORS Computing the \delta_x at the TECA and TCMS taking only into account the channeling effect 
    ######################################################################
    #EasyDeltaXtpst = np.sqrt(beta_x_at_teca * beta_tpst) * np.sin(delta_mu_xtpst) * TECA.bending_angle
    EasyDeltaXtpst = tw.loc['tpst.21760_entry'].delta_x
    ErrorEasyDeltaXtpst = np.sqrt(beta_tpst/beta_x_at_teca) * (np.cos(delta_mu_xtpst) + alpha_teca * np.sin(delta_mu_xtpst)) * (TECA.width)
    
    turn = N
    
    variable_names = [
        "turn",
        "beta_x_at_teca", "alpha_teca",
        "beta_tpst",
        "mu_x_teca", "mu_x_tpst", "delta_mu_xtpst",
        "EasyDeltaXtpst", 
        "ErrorEasyDeltaXtpst", 
        "x_NONchanneledTPST", "phaseAdvanceTecaTpst"
    ]

    variable_values = [
        turn,
        beta_x_at_teca, alpha_teca,
        beta_tpst,
        mu_x_teca, mu_x_tpst, delta_mu_xtpst,
        EasyDeltaXtpst, 
        ErrorEasyDeltaXtpst, 
        x_NONchanneledTPST, phaseAdvanceTecaTpst
    ]
    
    # Append the results to the DataFrame
    twiss_df = pd.concat([twiss_df, pd.DataFrame([variable_values], columns=variable_names)], ignore_index=True)

twiss_df = twiss_df.drop_duplicates(subset='turn')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(twiss_df['turn'], twiss_df['EasyDeltaXtpst']*1000, marker='o', linestyle='-', color='b')
plt.xlabel('Turn')
plt.ylabel(r"$\Delta x (mm)$ at the TPST")
plt.title('Turn vs separation at the TPST')
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(10, 6))
#error = np.abs(ErrorEasyDeltaXtpst)
plt.errorbar(twiss_df['turn'], twiss_df['x_NONchanneledTPST'] , yerr = np.abs(twiss_df["ErrorEasyDeltaXtpst"]), fmt='o-', label='Non-channeled particles')
plt.errorbar(twiss_df['turn'], twiss_df['x_NONchanneledTPST'] +  twiss_df["EasyDeltaXtpst"], yerr = np.abs(twiss_df["ErrorEasyDeltaXtpst"]), fmt='o-', label='Channeled particles')


plt.axhline(0.038, color='b', linestyle='--', label=r'MST entrance $ (38 mm )$')
plt.xlabel('Turn')
plt.ylabel('x (m)')
plt.title('Turn vs Position of the particles at the TPST')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
