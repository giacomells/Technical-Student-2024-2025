# %% [markdown]
# Trying to figure out how to have all the particles informations at every element of the LSS2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import minimize
import itertools 
import re
import os
import pickle
from cpymad.madx import Madx
import distutils

import warnings
from IPython.display import display, HTML, Markdown, clear_output

display(HTML("<style>.rendered_html { font-size: 17px; }</style>"))
display(HTML("<style>.container { width:90% !important; }</style>"))

def printmd(string):
    display(Markdown(string))
# warnings.filterwarnings('ignore')


plt.ion()
# Out:
# <style>.rendered_html { font-size: 17px; }</style>
# <style>.container { width:90% !important; }</style>

# %%
import pickle
import typing as t

import matplotlib.pyplot as plt
import numpy as np
import requests
import xobjects as xo
import xpart as xp
import xtrack as xt
import xcoll as xc
from cpymad.madx import Madx
import matplotlib as mpl
import matplotlib.patches as patches
import re

import septa

# %% [markdown]
# This SeptumInteraction class is made for the interaction of the particles with the septum.

# %%
class SeptumInteraction:
    def __init__(self, blade_position: float = 68e-3, thickness:float = 0.3e-3, kick:float = 1e-3, angle: float=-1.5, width:float = 0, aperture = 1e-2) -> None:
        self.blade_position = blade_position
        self.thickness = thickness
        self.kick = kick
        self.angle = angle  #the angle is actually not used in this model so it can be removed
        self.width = width      #This is the length in s of the element
        self.aperture = aperture
        pass

    def interact(self, particles: xp.Particles) -> t.Optional[t.Dict]:
        n_part = particles._num_active_particles

        # kick the particles beyond the blade and under the cathode
        if self.kick != 0:
            # only particles with this condition get a kick
            mask_kick = (particles.x[:n_part] > (self.blade_position + self.thickness)) & \
                        (particles.x[:n_part] < self.blade_position + self.thickness + self.aperture) & \
                        (particles.state[:n_part] == 1)
            particles.px[:n_part] += np.where(mask_kick, self.kick, 0)
        
        # particles with this condition are eliminated
        mask_eliminate = (particles.x[:n_part] < (self.blade_position + self.thickness)) | \
                        (particles.x[:n_part] > self.blade_position + self.thickness + self.aperture) & \
                        (particles.state[:n_part] == 1)
        
        particles.state[:n_part] = np.where(mask_eliminate, -1, particles.state[:n_part])

        return None

# %% [markdown]
# Functions to install the ZS, MST and MSE in the line.

# %%
def install_iterated_ZSsepta(line, install_zs=True, subdivision_number = 50):
    septa_names_with_apertures = []

    if install_zs:
        septum_names = septa.septum_namesZS
        subdivision_number = subdivision_number  
        width = septa.widthZSelements  # Length of the entire element in s
        heightZS = septa.heightZSelements
        blade_positionsZS = septa.blade_positionsZS
        aperture = septa.apertureZS
        
        # Installing monitors to measure the particles positions at their passage
        monitors = []
        
        for septum_name in septum_names:  # Cycle for every element
            n = septum_names.index(septum_name)
            # Assigning thickness based on the septum name
            if septum_name in ["zs.21633", "zs.21639"]:
                thickness = 0.6e-4
            else:
                thickness = 1e-4
            
            for i in range(subdivision_number):  # Cycle for subdivision
                # Scalo verso il basso la blade_position per ogni suddivisione
                blade_position = blade_positionsZS[n] - i * heightZS / subdivision_number
                index_of_suddivision = str(i)
                
                # Calculate the position along the line (s)
                at_s_position = line.get_s_position(septum_name) + i * (width / subdivision_number)
            
                # Inserting the anode
                zs = xt.BeamInteraction(
                    length = 0.0,
                    interaction_process = SeptumInteraction(
                        blade_position = blade_position,
                        thickness = thickness,
                        kick = septa.kickZS / (subdivision_number),
                        angle = -1.5, #the angle is actually not used in this model so it can be removed
                        width = width / subdivision_number,   #This is the length in s of the element
                        aperture = aperture
                    ),
                )
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision + ".sep",
                    element = zs,
                    at_s = at_s_position  
                )
                septa_names_with_apertures.append(septum_name + "_" + index_of_suddivision + ".sep")
                
                
                # Installing monitors for every sliced element
                monitor = xt.BeamSizeMonitor(stop_at_turn=1)
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision +".monitor",
                    element = monitor,
                    at_s = at_s_position  # inserting the monitors at the desired position
                )
                monitors.append(monitor) #CHECK ONE_TURN_MONITOR IN TRACKING
                
                            

        #Installing monitor at the ZS end to obtatin the beam's envelop outside the ZS
        last_septum_name = septum_names[-1]
        last_s_position = line.get_s_position(last_septum_name) + width # Position after the last septum
        exit_monitor = xt.BeamSizeMonitor(stop_at_turn=1)
        
        line.insert_element(
            name = "ZS_exit.monitor",
            element = exit_monitor,
            at_s = last_s_position  # Insert monitor after the last septum element
        )
        
        #Installing monitor outside the MST to obtatin the beam's envelop outside the MST
        outside_monitors_numberZS = 8
        for i in range(outside_monitors_numberZS):
            outside_monitor_number = str(i)
            last_septum_name = septum_names[-1]
            last_s_position = line.get_s_position(last_septum_name) + width * i * 1.2  # Position after the last septum
            outside_monitor = xt.BeamSizeMonitor(stop_at_turn = 1)
            
            line.insert_element(
                name = "ZS_outside_" + outside_monitor_number + ".monitor",
                element = outside_monitor,
                at_s = last_s_position  # Insert monitor after the last septum element for i times
            )
            monitors.append(outside_monitor) 
        
        #Installing monitor at the entrance
        first_s_position = line.get_s_position('zs.21633_0.monitor') - width/subdivision_number * 0.99 # Position after the last septum
        monitor = xt.BeamSizeMonitor(stop_at_turn=1)
        
        line.insert_element(
            name = "ZSEntry.monitor",
            element = monitor,
            at_s = first_s_position  # Insert monitor after the last septum element
        )        
                
    return septa_names_with_apertures

# %%
def install_iterated_MSTsepta(line, install_mst=True, subdivision_number = 50):
    septa_names_with_apertures = []

    subdivision_number = subdivision_number  
    
    if install_mst:
        
        # Defining variable for the MST elements
        blade_positionTPST =septa.blade_positionTPST
        widthTPST = septa.widthMSTelements  # Length of the entire element in s
        heightTPST = septa.heightTPST   
        apertureTPST = septa.apertureTPST
        thicknessTPST = septa.thicknessTPST
        kickTPST = septa.kickTPST
        
        # Defining variable for the MST elements
        septum_names = septa.septum_namesMST
        widthMST = septa.widthMSTelements  # Width of the entire element
        heightMST = septa.heightMSTelements
        blade_positionsMST = septa.blade_positionsMST
        apertureMST = septa.apertureMST
        thicknessMST = septa.thicknessMST
        kickMST = septa.kickMST
        
        # Installing monitors to measure the particles positions at their passage
        monitors = []
        
        #INSTALLING THE FIRST ELEMENT TPST WHICH IS ONLY A MASK
        for i in range(subdivision_number):
            index_of_suddivisionTPST = str(i)
            
            blade_positionTPSTsliced = blade_positionTPST + i * heightTPST / subdivision_number
            at_s_positionTPST = line.get_s_position("tpst.21760_entry") + i * (widthTPST / subdivision_number)
                
                
            tpst = xt.BeamInteraction(
                length=0.0,
                interaction_process=SeptumInteraction(
                    blade_position = blade_positionTPSTsliced, thickness = thicknessTPST, kick = kickTPST, width = widthTPST / subdivision_number, aperture = apertureTPST),
                )
            line.insert_element(name = "tpst.21760_"+ index_of_suddivisionTPST + ".sep", element = tpst, at_s = at_s_positionTPST) 
            septa_names_with_apertures.append("tpst.21760" + ".sep")

            # Installing monitors for every sliced element
            monitorTPST = xt.BeamSizeMonitor(stop_at_turn=1)
            line.insert_element(
                name = "tpst.21760_"+ index_of_suddivisionTPST +".monitor",
                element = monitorTPST, at_s = at_s_positionTPST  # inserting the monitors at the desired position
                )
            monitors.append(monitorTPST) #CHECK ONE_TURN_MONITOR IN TRACKING
                

                
        # INSTALLING MST
        for septum_name in septum_names:  # Cycle for every element
            n = septum_names.index(septum_name)
            
            for i in range(subdivision_number):  # Cycle for subdivision
                index_of_suddivision = str(i)
                
                # Scaling down for every slice 
                blade_positionMST = blade_positionsMST[n] + i * heightMST / subdivision_number
                
                # Calculate the position along the line (s)
                at_s_position = line.get_s_position(septum_name) + i * (widthMST / subdivision_number)

                # Inserting the anode
                zs = xt.BeamInteraction(
                    length = 0.0,
                    interaction_process = SeptumInteraction(
                        blade_position = blade_positionMST,
                        thickness = thicknessMST,
                        kick = kickMST / subdivision_number,
                        angle = -1.5,   #the angle is actually not used in this model so it can be removed
                        width = widthMST / subdivision_number,  
                        aperture = apertureMST
                    ),
                )
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision + ".sep",
                    element = zs,
                    at_s = at_s_position  
                )
                septa_names_with_apertures.append(septum_name + "_" + index_of_suddivision + ".sep")
                
                
                # Installing monitors for every sliced element
                monitor = xt.BeamSizeMonitor(stop_at_turn=1)
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision +".monitor",
                    element = monitor,
                    at_s = at_s_position  # inserting the monitors at the desired position
                )
                monitors.append(monitor) #CHECK ONE_TURN_MONITOR IN TRACKING
                
                            

        #Installing monitor at the MST end to obtatin the beam's envelop outside the MST
        last_septum_name = septum_names[-1]
        last_s_position = line.get_s_position(last_septum_name) + widthMST # Position after the last septum
        exit_monitor = xt.BeamSizeMonitor(stop_at_turn=1)
        
        line.insert_element(
            name = "MST_exit.monitor",
            element = exit_monitor,
            at_s = last_s_position  # Insert monitor after the last septum element
        )
        
        #Installing monitor outside the MST to obtatin the beam's envelop outside the MST
        last_septum_name = septum_names[-1]
        last_s_position = line.get_s_position(last_septum_name) + widthMST * 2  # Position after the last septum
        outside_monitor = xt.BeamSizeMonitor(stop_at_turn = 1)
        
        line.insert_element(
            name = "MST_outside.monitor",
            element = outside_monitor,
            at_s = last_s_position  # Insert monitor after the last septum element
        )

        monitors.append(exit_monitor)  
        
        #Installing monitor outside the MST to obtatin the beam's envelop outside the MST
        outside_monitors_numberMST = 4
        for i in range(outside_monitors_numberMST):
            outside_monitor_number = str(i)
            last_septum_name = septum_names[-1]
            last_s_position = line.get_s_position(last_septum_name) + widthMST * i * 1.2  # Position after the last septum
            outside_monitor = xt.BeamSizeMonitor(stop_at_turn = 1)
            
            line.insert_element(
                name = "MST_outside_" + outside_monitor_number + ".monitor",
                element = outside_monitor,
                at_s = last_s_position  # Insert monitor after the last septum element for i times
            )
            monitors.append(outside_monitor) 
        
                
    return septa_names_with_apertures

# %%
def install_iterated_MSEsepta(line, install_mse=True, subdivision_number = 50):
    septa_names_with_apertures = []

    if install_mse:
        septum_names = septa.septum_namesMSE
        subdivision_number = subdivision_number  
        width = septa.widthMSEelements # Length of the entire element in s
        blade_positionsMSEentrance = septa.blade_positionsMSEentrance
        blade_positionMSEexits = septa.blade_positionsMSEexits
        aperture = septa.apertureMSE
        thicknessMSE = septa.thicknessMSE
        kick = septa.kickMSE
        
        # Installing monitors to measure the particles positions at their passage
        monitors = []
        
        for septum_name in septum_names:  # Cycle for every element
            n = septum_names.index(septum_name)
            heightMSE = blade_positionsMSEentrance[n] - blade_positionMSEexits[n]    
            
            for i in range(subdivision_number):  # Cycle for subdivision
                index_of_suddivision = str(i)
                # Scaling the slices
                blade_position = blade_positionsMSEentrance[n] - i * heightMSE / subdivision_number
                at_s_position = line.get_s_position(septum_name) + i * (width / subdivision_number)
            
                # Inserting the anode
                MSE = xt.BeamInteraction(
                    length = 0.0,
                    interaction_process = SeptumInteraction(
                        blade_position = blade_position,
                        thickness = thicknessMSE,
                        kick = kick / (subdivision_number),
                        angle = -1.5,     #the angle is actually not used in this model so it can be removed
                        width = width / subdivision_number,  #This is the length in s of the element
                        aperture = aperture
                    ),
                )
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision + ".sep",
                    element = MSE,
                    at_s = at_s_position  
                )
                septa_names_with_apertures.append(septum_name + "_" + index_of_suddivision + ".sep")
                
                
                # Installing monitors for every sliced element
                monitor = xt.BeamSizeMonitor(stop_at_turn=1)
                line.insert_element(
                    name = septum_name + "_" + index_of_suddivision +".monitor",
                    element = monitor,
                    at_s = at_s_position  # inserting the monitors at the desired position
                )
                monitors.append(monitor) #CHECK ONE_TURN_MONITOR IN TRACKING
                
                            

        #Installing monitor at the MSE end to obtatin the beam's envelop outside the MSE
        last_septum_name = septum_names[-1]
        last_s_position = line.get_s_position(last_septum_name) + width # Position after the last septum
        exit_monitor = xt.BeamSizeMonitor(stop_at_turn=1)
        
        line.insert_element(
            name = "MSE_exit.monitor",
            element = exit_monitor,
            at_s = last_s_position  # Insert monitor after the last septum element
        )
        
        #Installing monitor outside the MST to obtatin the beam's envelop outside the MST
        outside_monitors_numberMSE = 8
        for i in range(outside_monitors_numberMSE):
            outside_monitor_number = str(i)
            last_septum_name = septum_names[-1]
            last_s_position = line.get_s_position(last_septum_name) + width * i * 1.5  # Position after the last septum
            outside_monitor = xt.BeamSizeMonitor(stop_at_turn = 1)
            
            line.insert_element(
                name = "MSE_outside_" + outside_monitor_number + ".monitor",
                element = outside_monitor,
                at_s = last_s_position  # Insert monitor after the last septum element for i times
            )
            monitors.append(outside_monitor) 
                
                
    return septa_names_with_apertures

# %%
def draw_sep_elements(ax, line):
    # getting the elements from the line after installing them with install_septa function
    septa_elements = [el for el in line.element_dict.keys() if ".sep" in el]
    
    for septum_name in septa_elements:
        element = line[septum_name]
        interaction_process = element.interaction_process

        # Getting the information
        blade_position = interaction_process.blade_position
        thickness = interaction_process.thickness
        width = interaction_process.width   #This is the length in s of the element
        s_position = line.get_table()['s', septum_name]
        aperture = interaction_process.aperture
        
        # Printing the element's informations for a check
        print(f"Element: {septum_name}, s_position: {s_position}, blade_position: {blade_position}, thickness: {thickness}")
        
        if "_0.sep" in septum_name:
            # Writing the name of the element at the s_position
            ax.text(s_position, ax.get_ylim()[1], septum_name, ha='center', va='bottom', rotation=90, fontsize=10, color='blue')

        # . Disegna un rettangolo nero verticale per la lama
        ax.add_patch(plt.Rectangle((s_position, blade_position), width, thickness , color='black'))
        
        # . Disegna un rettangolo nero verticale per la l'anodo
        ax.add_patch(plt.Rectangle((s_position, blade_position + thickness + aperture), width, ax.get_ylim()[1], color='black'))
        
        
    # Settaggi degli assi
    ax.set_xlabel('s (m)')
    ax.set_ylabel('x (m)')
    ax.legend(loc='lower right')

    return ax

# %%
def get_beam(line, twiss):
    out = line.record_last_track.to_dict()
    out = pd.DataFrame(out['data'])
    elements = line.get_table().to_pandas()
    elements['at_element'] = elements.index
    out = out.join(elements, on='at_element', rsuffix='_elem', how='inner')
    #out = out.join(twiss.loc[:, ['tilt']], on='name', rsuffix='_twiss', how='inner')
    out.index = out['name']
    
    cols = ['x', 'px', 'y', 'py', 'zeta', 'delta', 'state']
    #out_selected = untilt(out.loc[:, cols + ['s', 'tilt', 'at_element']])
    #out_selected = out.loc[:, cols + ['s', 'tilt', 'at_element', 'particle_id']]
    out_selected = out.loc[:, cols + ['s', 'at_element', 'particle_id']]
    
    return out_selected

# %%
p = septa.p
momentum = p
Brho = septa.Brho

N_EX = septa.N_EX
N_EY = septa.N_EY
DPP = septa.DPP

septum_aperture_position = septa.septum_aperture_position

ZSentrances = septa.ZSentrances
ZSexits = septa.ZSexits

MSTentrances = septa.MSTentrances
MSTexits = septa.MSTexits

# %%
# Define slicing strategies for thick elements, if needed
Strategy = xt.slicing.Strategy
Teapot = xt.slicing.Teapot

line = xt.Line.from_json("./sps_with_extraction_sliced_quads.json")
# Out:
# Loading line from dict:   0%|          | 0/9960 [00:00<?, ?it/s]
# Done loading line from dict.

# %% [markdown]
# I took the following code from another example: https://gitlab.cern.ch/sps-projects/sx_xsuite_sps/-/tree/main/sx_xsuite_sps?ref_type=heads

# %%
# Define a rectangular limit for the septum aperture
septum = xt.LimitRect(min_x=-1., max_x=septum_aperture_position, # CHECK IF IT IS INVERTED MIN_X AND MAX_X
                      min_y=-1., max_y=1.)  # Rectangle defined by min/max values

# Insert the defined septum element into the line at a specified index
line.insert_element(name="zs_aperture", element=septum, index='zs.21633_entry')
line.cycle("zs_aperture", inplace=True)  # Cycle the line to ensure proper setup
line.build_tracker()  # Build the tracker for the simulation


# Switch on extraction bump
line.vv["extr_bump_knob"] = 0.88

# Extraction tunes
opt = line.match(solve=False,
    vary=[
        xt.VaryList(['kqf', 'kqd'], step=1e-7),   # Varying quadrupole focal strengths
        xt.VaryList(['qph_setvalue', 'qpv_setvalue'], step=1e-4),   # Varying phase values
    ],
    targets=[
        xt.TargetSet(qx=26.666666666, qy=26.58, tol=1e-5),    # Desired target tunes
        xt.TargetSet(dqx=-1 * 26., dqy=0.47 * 26., tol=1e-3),    # Desired dispersion values
    ])

opt.solve()  # Solve the matching problem to find optimal parameters

# Switch on extraction sextupoles
line.vv["sps_on_extraction"] = 1.0
# Out:
#
# Optimize - start penalty: 9.664
# Matching: model call n. 13 penalty = 1.1687e-05
# Optimize - end penalty:  1.16874e-05

# %%
# Convert the line setup to a DataFrame for easier analysis
line_df = line.to_pandas()

line.vars.get_table()  # Retrieve variable table for inspection

# Specify number of particles for the simulation
n_part = 200 

# Generate normalized 2D Gaussian distributions for particle coordinates and momenta
x_norm, px_norm = xp.generate_2D_gaussian(num_particles=n_part)
y_norm, py_norm = xp.generate_2D_gaussian(num_particles=n_part)

# Initialize longitudinal coordinate and momentum spread
zeta = 0.0
dpp = np.random.rand(n_part) * DPP

# Build the particle distribution based on the generated parameters
particles = line.build_particles(
    method="4d",
    zeta=zeta,
    delta=dpp,
    x_norm=x_norm,
    px_norm=px_norm,
    y_norm=y_norm,
    py_norm=py_norm,
    nemitt_x=N_EX,   # Normalized emittance in x direction
    nemitt_y=N_EY,   # Normalized emittance in y direction
)

# %%
line.discard_tracker()
line.build_tracker(_context=xo.ContextCpu())
line.reset_s_at_end_turn = False
num_turns = 100
ele_stop = line.element_names.index('zs.21633_entry')

line.track(
    particles,
    ele_stop = ele_stop,
    num_turns = num_turns,
    turn_by_turn_monitor='ONE_TURN_EBE',
    time=True,
)
#line.time_last_track
rec = line.record_last_track
twissDFinitial = line.twiss().to_pandas()

# %%
dfInitial = get_beam(line, twissDFinitial)

#Getting the minimum  and maximum values of the beam
x_minInitial = dfInitial.groupby('s').x.min()
print("The minmum values at the locations are:")
print(x_minInitial)


x_maxInitial = dfInitial.groupby('s').x.max()
print("The maximum values at the locations are:")
print(x_maxInitial)

dfInitial.index.drop_duplicates()

dfCirculating = get_beam(line, twissDFinitial)

#Getting the minimum  and maximum values of the beam
x_min = dfCirculating.groupby('s').x.min()
print("The minmum values of the circulating beam at the locations(s) are:")
print(x_min)


x_max = dfCirculating.groupby('s').x.max()
print("The maximum values of the circulating at the locations(s) are:")
print(x_max)
# Out:
# The minmum values at the locations are:
# s
# 0.0000       0.041364
# 1.5650       0.039932
# 3.1300       0.038500
# 3.9100       0.037786
# 5.4750       0.036353
#                ...
# 6907.5702    0.043835
# 6908.3284    0.043895
# 6909.0866    0.043577
# 6909.8448    0.042883
# 6911.5038    0.041365
# Name: x, Length: 4154, dtype: float64
# The maximum values at the locations are:
# s
# 0.0000       0.041373
# 1.5650       0.039941
# 3.1300       0.038508
# 3.9100       0.037794
# 5.4750       0.036362
#                ...
# 6907.5702    0.043844
# 6908.3284    0.043904
# 6909.0866    0.043585
# 6909.8448    0.042891
# 6911.5038    0.041373
# Name: x, Length: 4154, dtype: float64
# The minmum values of the circulating beam at the locations(s) are:
# s
# 0.0000       0.041364
# 1.5650       0.039932
# 3.1300       0.038500
# 3.9100       0.037786
# 5.4750       0.036353
#                ...
# 6907.5702    0.043835
# 6908.3284    0.043895
# 6909.0866    0.043577
# 6909.8448    0.042883
# 6911.5038    0.041365
# Name: x, Length: 4154, dtype: float64
# The maximum values of the circulating at the locations(s) are:
# s
# 0.0000       0.041373
# 1.5650       0.039941
# 3.1300       0.038508
# 3.9100       0.037794
# 5.4750       0.036362
#                ...
# 6907.5702    0.043844
# 6908.3284    0.043904
# 6909.0866    0.043585
# 6909.8448    0.042891
# 6911.5038    0.041373
# Name: x, Length: 4154, dtype: float64

# %% [markdown]
# In the next I am creating a copy of the extracted particles.

# %%
# Convert to DataFrame pandas
particles_df = particles.to_pandas()

aperture_acceptance = 2e-3

# KEEP THE ORIGINAL PARTICLES WITHOUT MAKING A COPY

# Selecting extracted particles
particles_extracted_df = particles_df[particles_df['x']  > septum_aperture_position - aperture_acceptance]
#particle_extracted_df = particles_df['state'== 0]  

# number of extracted particles
n_part_extracted = len(particles_extracted_df)
print(f"Number of extracted particles: {n_part_extracted}")

if n_part_extracted > 0:
    particlesExtracted = xt.Particles(
        x=np.array(particles_extracted_df['x']),
        px=np.array(particles_extracted_df['px']),
        y=np.array(particles_extracted_df['y']),
        py=np.array(particles_extracted_df['py']),
        zeta=np.array(particles_extracted_df['zeta']),
        delta=np.array(particles_extracted_df['delta']),
        particle_id=np.array(particles_extracted_df['particle_id']),
    )
# Out:
# Number of extracted particles: 37

# %% [markdown]
# Plotting the phase space of the extracted particles

# %%
plt.figure(2)
plt.plot(particlesExtracted.x, particlesExtracted.px, ".", label='Extracted Particles')
plt.axvline(septum_aperture_position, color="red", ls="--", label='Septum Aperture')
plt.xlabel(r"$x$ [m]")
plt.ylabel(r"$p_x$ [rad]")
plt.legend()

plt.show()

# %% [markdown]
# In the next cell I am creating a new line for a easier analysis of the extracted particles. In this line I install all the septum elements that in the previous line were not installed. The reason of this is that the SeptumInteraction class would eliminate the particles outside the aperture.
#
# In the near future I will implement a single line with a different SeptumInteraction class that will not eliminate the particles outside the aperture so that it will be possible to simulate a realistic spill.
#
# The idea is to create a SeptumeInteraction that eliminates only the particles that hit the blades.

# %%
LSS2 = xt.Line.from_json("./sps_with_extraction_sliced_quads.json")

subdivision_number = 10

LSS2.discard_tracker()

monitorsZS = install_iterated_ZSsepta(LSS2, subdivision_number = subdivision_number)
monitorsMST = install_iterated_MSTsepta(LSS2, subdivision_number = subdivision_number)
monitorsMSE = install_iterated_MSEsepta(LSS2, subdivision_number = subdivision_number)
#LSS2.cycle("zs.21633_0.monitor")
LSS2.cycle("zs.21633_entry")

particlesExtractedInitial = particlesExtracted.copy()
# Out:
# Loading line from dict:   0%|          | 0/9960 [00:00<?, ?it/s]
# Done loading line from dict.
# Slicing line:   0%|          | 0/9962 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9965 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9968 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9971 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9974 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9977 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9980 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9983 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9986 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9991 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9994 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/9997 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10000 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10003 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10006 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10009 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10012 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10015 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10020 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10023 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10026 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10029 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10032 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10035 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10038 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10041 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10044 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10049 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10052 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10055 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10058 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10061 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10064 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10067 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10070 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10073 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10078 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10081 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10084 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10087 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10090 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10093 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10096 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10099 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10102 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10105 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10108 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10110 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10112 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10118 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10120 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10122 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10124 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10126 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10130 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10133 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10136 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10139 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10142 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10145 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10148 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10151 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10154 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10159 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10162 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10165 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10168 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10171 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10174 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10177 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10180 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10183 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10188 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10191 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10194 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10197 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10200 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10203 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10206 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10209 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10212 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10217 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10220 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10223 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10226 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10229 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10232 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10235 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10238 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10241 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10244 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10246 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10253 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10255 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10259 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10263 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10266 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10269 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10272 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10275 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10278 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10281 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10284 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10287 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10292 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10295 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10298 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10301 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10304 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10307 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10310 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10313 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10316 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10321 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10324 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10327 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10330 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10333 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10336 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10339 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10342 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10345 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10350 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10353 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10356 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10359 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10362 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10365 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10368 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10371 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10374 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10379 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10382 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10385 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10388 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10391 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10394 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10397 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10400 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10403 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10406 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10409 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10411 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10413 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10415 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10421 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10423 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/10425 [00:00<?, ?it/s]

# %%
LSS2.discard_tracker()
LSS2.build_tracker(_context=xo.ContextCpu())



ele_startZS = LSS2.element_names.index('zs.21633_entry')
#ele_stop = LSS2.element_names.index('zs.21676_'  + str(subdivision_number - 1) + '.monitor') + 5
ele_stop = LSS2.element_names.index('mse.21872_'  + str(subdivision_number - 1) + '.monitor') + 100


LSS2.track(
    particlesExtracted,
    ele_start = ele_startZS,
    ele_stop = ele_stop,
    num_turns = 1,
    turn_by_turn_monitor = 'ONE_TURN_EBE'
    )
out = LSS2.record_last_track
twissDF = LSS2.twiss().to_pandas()
# Out:
# The line has collective elements.
# In the twiss computation collective elements are replaced by drifts

# %%
df = get_beam(LSS2, twissDF)

#Getting the minimum  and maximum values of the beam
x_min = df.groupby('s').x.min()
print("The minmum values at the locations are:")
print(x_min)


x_max = df.groupby('s').x.max()
print("The maximum values at the locations are:")
print(x_max)
# Out:
# The minmum values at the locations are:
# s
# 0.000000      0.000000
# 1.258100      0.066254
# 1.565000      0.065804
# 1.875000      0.067606
# 2.185000      0.067144
#                 ...
# 125.978800    0.839605
# 126.338791    0.831463
# 132.598809    0.689644
# 132.998791    0.680593
# 139.258809    0.538793
# Name: x, Length: 254, dtype: float64
# The maximum values at the locations are:
# s
# 0.000000      0.082200
# 1.258100      0.079967
# 1.565000      0.079423
# 1.875000      0.078875
# 2.185000      0.078331
#                 ...
# 125.978800    0.851329
# 126.338791    0.843053
# 132.598809    0.698948
# 132.998791    0.689752
# 139.258809    0.545701
# Name: x, Length: 254, dtype: float64

# %%
s_position_Max_min = df.s

# %%
# Stampa della posizione e altre proprietà dei monitor
for i, monitor_name in enumerate(LSS2.element_names):
    if "monitor" in monitor_name:
        monitor = LSS2.element_dict[monitor_name]
        print(monitor_name)
        print(f"         Monitor position s: {LSS2.get_s_position(monitor_name)}")
        print(f"         Particles detected: {monitor.count}")
        print(f"         Mean x of the beam: {monitor.x_mean} +/- {monitor.x_std}")
        print(f"         X Variances of the beam: {monitor.x_var}")
# Out:
# ZSEntry.monitor
#          Monitor position s: 1.258100000000013
#          Particles detected: [37.]
#          Mean x of the beam: [0.07170559] +/- [0.003647]
#          X Variances of the beam: [1.33006312e-05]
# zs.21633_0.monitor
#          Monitor position s: 1.565
#          Particles detected: [37.]
#          Mean x of the beam: [0.07121813] +/- [0.00362108]
#          X Variances of the beam: [1.31122456e-05]
# zs.21633_1.monitor
#          Monitor position s: 1.8749999999999454
#          Particles detected: [30.]
#          Mean x of the beam: [0.07175213] +/- [0.00320046]
#          X Variances of the beam: [1.0242918e-05]
# zs.21633_2.monitor
#          Monitor position s: 2.184999999999891
#          Particles detected: [30.]
#          Mean x of the beam: [0.07125813] +/- [0.00317653]
#          X Variances of the beam: [1.00903405e-05]
# zs.21633_3.monitor
#          Monitor position s: 2.4950000000000636
#          Particles detected: [30.]
#          Mean x of the beam: [0.07076686] +/- [0.0031526]
#          X Variances of the beam: [9.93891442e-06]
# zs.21633_4.monitor
#          Monitor position s: 2.805000000000009
#          Particles detected: [30.]
#          Mean x of the beam: [0.07027832] +/- [0.00312868]
#          X Variances of the beam: [9.78863962e-06]
# zs.21633_5.monitor
#          Monitor position s: 3.1149999999999545
#          Particles detected: [30.]
#          Mean x of the beam: [0.0697925] +/- [0.00310476]
#          X Variances of the beam: [9.63951614e-06]
# zs.21633_6.monitor
#          Monitor position s: 3.4249999999998453
#          Particles detected: [30.]
#          Mean x of the beam: [0.06930941] +/- [0.00308083]
#          X Variances of the beam: [9.49154398e-06]
# zs.21633_7.monitor
#          Monitor position s: 3.735000000000018
#          Particles detected: [30.]
#          Mean x of the beam: [0.06882905] +/- [0.00305691]
#          X Variances of the beam: [9.34472313e-06]
# zs.21633_8.monitor
#          Monitor position s: 4.0449999999999635
#          Particles detected: [30.]
#          Mean x of the beam: [0.06835142] +/- [0.00303299]
#          X Variances of the beam: [9.19905358e-06]
# zs.21633_9.monitor
#          Monitor position s: 4.354999999999909
#          Particles detected: [30.]
#          Mean x of the beam: [0.06787651] +/- [0.00300908]
#          X Variances of the beam: [9.05453533e-06]
# zs.21639_0.monitor
#          Monitor position s: 5.474999999999973
#          Particles detected: [30.]
#          Mean x of the beam: [0.06617058] +/- [0.00292267]
#          X Variances of the beam: [8.5419976e-06]
# zs.21639_1.monitor
#          Monitor position s: 5.784999999999918
#          Particles detected: [30.]
#          Mean x of the beam: [0.06570113] +/- [0.00289876]
#          X Variances of the beam: [8.4027896e-06]
# zs.21639_2.monitor
#          Monitor position s: 6.094999999999864
#          Particles detected: [30.]
#          Mean x of the beam: [0.06523441] +/- [0.00287484]
#          X Variances of the beam: [8.26473287e-06]
# zs.21639_3.monitor
#          Monitor position s: 6.405000000000037
#          Particles detected: [30.]
#          Mean x of the beam: [0.06477041] +/- [0.00285093]
#          X Variances of the beam: [8.12782741e-06]
# zs.21639_4.monitor
#          Monitor position s: 6.714999999999982
#          Particles detected: [30.]
#          Mean x of the beam: [0.06430915] +/- [0.00282703]
#          X Variances of the beam: [7.99207322e-06]
# zs.21639_5.monitor
#          Monitor position s: 7.0249999999999275
#          Particles detected: [30.]
#          Mean x of the beam: [0.06385061] +/- [0.00280312]
#          X Variances of the beam: [7.85747028e-06]
# zs.21639_6.monitor
#          Monitor position s: 7.334999999999818
#          Particles detected: [30.]
#          Mean x of the beam: [0.0633948] +/- [0.00277921]
#          X Variances of the beam: [7.7240186e-06]
# zs.21639_7.monitor
#          Monitor position s: 7.644999999999991
#          Particles detected: [30.]
#          Mean x of the beam: [0.06294172] +/- [0.00275531]
#          X Variances of the beam: [7.59171817e-06]
# zs.21639_8.monitor
#          Monitor position s: 7.954999999999936
#          Particles detected: [30.]
#          Mean x of the beam: [0.06249136] +/- [0.0027314]
#          X Variances of the beam: [7.46056898e-06]
# zs.21639_9.monitor
#          Monitor position s: 8.264999999999882
#          Particles detected: [30.]
#          Mean x of the beam: [0.06204373] +/- [0.0027075]
#          X Variances of the beam: [7.33057103e-06]
# zs.21655_0.monitor
#          Monitor position s: 9.384999999999717
#          Particles detected: [30.]
#          Mean x of the beam: [0.06043636] +/- [0.00262116]
#          X Variances of the beam: [6.87049331e-06]
# zs.21655_1.monitor
#          Monitor position s: 9.694999999999663
#          Particles detected: [30.]
#          Mean x of the beam: [0.05999419] +/- [0.00259727]
#          X Variances of the beam: [6.74580537e-06]
# zs.21655_2.monitor
#          Monitor position s: 10.004999999999608
#          Particles detected: [30.]
#          Mean x of the beam: [0.05955474] +/- [0.00257338]
#          X Variances of the beam: [6.62226865e-06]
# zs.21655_3.monitor
#          Monitor position s: 10.314999999999781
#          Particles detected: [30.]
#          Mean x of the beam: [0.05911803] +/- [0.00254949]
#          X Variances of the beam: [6.49988313e-06]
# zs.21655_4.monitor
#          Monitor position s: 10.624999999999726
#          Particles detected: [30.]
#          Mean x of the beam: [0.05868404] +/- [0.0025256]
#          X Variances of the beam: [6.37864882e-06]
# zs.21655_5.monitor
#          Monitor position s: 10.934999999999672
#          Particles detected: [30.]
#          Mean x of the beam: [0.05825278] +/- [0.00250171]
#          X Variances of the beam: [6.2585657e-06]
# zs.21655_6.monitor
#          Monitor position s: 11.244999999999562
#          Particles detected: [30.]
#          Mean x of the beam: [0.05782425] +/- [0.00247783]
#          X Variances of the beam: [6.13963378e-06]
# zs.21655_7.monitor
#          Monitor position s: 11.554999999999735
#          Particles detected: [30.]
#          Mean x of the beam: [0.05739845] +/- [0.00245395]
#          X Variances of the beam: [6.02185304e-06]
# zs.21655_8.monitor
#          Monitor position s: 11.86499999999968
#          Particles detected: [30.]
#          Mean x of the beam: [0.05697537] +/- [0.00243007]
#          X Variances of the beam: [5.90522348e-06]
# zs.21655_9.monitor
#          Monitor position s: 12.174999999999626
#          Particles detected: [30.]
#          Mean x of the beam: [0.05655502] +/- [0.00240619]
#          X Variances of the beam: [5.78974509e-06]
# zs.21671_0.monitor
#          Monitor position s: 13.294999999999689
#          Particles detected: [30.]
#          Mean x of the beam: [0.0550462] +/- [0.00231994]
#          X Variances of the beam: [5.38212476e-06]
# zs.21671_1.monitor
#          Monitor position s: 13.604999999999634
#          Particles detected: [30.]
#          Mean x of the beam: [0.05463131] +/- [0.00229607]
#          X Variances of the beam: [5.27195617e-06]
# zs.21671_2.monitor
#          Monitor position s: 13.91499999999958
#          Particles detected: [30.]
#          Mean x of the beam: [0.05421914] +/- [0.00227221]
#          X Variances of the beam: [5.16293873e-06]
# zs.21671_3.monitor
#          Monitor position s: 14.224999999999753
#          Particles detected: [30.]
#          Mean x of the beam: [0.05380971] +/- [0.00224835]
#          X Variances of the beam: [5.05507243e-06]
# zs.21671_4.monitor
#          Monitor position s: 14.534999999999698
#          Particles detected: [30.]
#          Mean x of the beam: [0.053403] +/- [0.00222449]
#          X Variances of the beam: [4.94835727e-06]
# zs.21671_5.monitor
#          Monitor position s: 14.844999999999644
#          Particles detected: [30.]
#          Mean x of the beam: [0.05299902] +/- [0.00220063]
#          X Variances of the beam: [4.84279325e-06]
# zs.21671_6.monitor
#          Monitor position s: 15.154999999999534
#          Particles detected: [30.]
#          Mean x of the beam: [0.05259776] +/- [0.00217678]
#          X Variances of the beam: [4.73838035e-06]
# zs.21671_7.monitor
#          Monitor position s: 15.464999999999707
#          Particles detected: [30.]
#          Mean x of the beam: [0.05219924] +/- [0.00215293]
#          X Variances of the beam: [4.63511858e-06]
# zs.21671_8.monitor
#          Monitor position s: 15.774999999999652
#          Particles detected: [30.]
#          Mean x of the beam: [0.05180344] +/- [0.00212909]
#          X Variances of the beam: [4.53300793e-06]
# zs.21671_9.monitor
#          Monitor position s: 16.084999999999596
#          Particles detected: [30.]
#          Mean x of the beam: [0.05141037] +/- [0.00210524]
#          X Variances of the beam: [4.43204838e-06]
# ZS_outside_0.monitor
#          Monitor position s: 17.20499999999966
#          Particles detected: [30.]
#          Mean x of the beam: [0.0500001] +/- [0.00201913]
#          X Variances of the beam: [4.07688281e-06]
# zs.21676_0.monitor
#          Monitor position s: 17.20499999999966
#          Particles detected: [30.]
#          Mean x of the beam: [0.0500001] +/- [0.00201913]
#          X Variances of the beam: [4.07688281e-06]
# zs.21676_1.monitor
#          Monitor position s: 17.514999999999606
#          Particles detected: [30.]
#          Mean x of the beam: [0.04961249] +/- [0.0019953]
#          X Variances of the beam: [3.98123284e-06]
# zs.21676_2.monitor
#          Monitor position s: 17.82499999999955
#          Particles detected: [30.]
#          Mean x of the beam: [0.0492276] +/- [0.00197148]
#          X Variances of the beam: [3.88673395e-06]
# zs.21676_3.monitor
#          Monitor position s: 18.134999999999724
#          Particles detected: [30.]
#          Mean x of the beam: [0.04884545] +/- [0.00194766]
#          X Variances of the beam: [3.79338614e-06]
# zs.21676_4.monitor
#          Monitor position s: 18.44499999999967
#          Particles detected: [30.]
#          Mean x of the beam: [0.04846601] +/- [0.00192385]
#          X Variances of the beam: [3.70118941e-06]
# zs.21676_5.monitor
#          Monitor position s: 18.754999999999615
#          Particles detected: [30.]
#          Mean x of the beam: [0.04808931] +/- [0.00190004]
#          X Variances of the beam: [3.61014376e-06]
# zs.21676_6.monitor
#          Monitor position s: 19.064999999999507
#          Particles detected: [30.]
#          Mean x of the beam: [0.04771534] +/- [0.00187623]
#          X Variances of the beam: [3.52024917e-06]
# zs.21676_7.monitor
#          Monitor position s: 19.37499999999968
#          Particles detected: [30.]
#          Mean x of the beam: [0.04734409] +/- [0.00185243]
#          X Variances of the beam: [3.43150564e-06]
# zs.21676_8.monitor
#          Monitor position s: 19.684999999999626
#          Particles detected: [30.]
#          Mean x of the beam: [0.04697557] +/- [0.00182864]
#          X Variances of the beam: [3.34391316e-06]
# zs.21676_9.monitor
#          Monitor position s: 19.99499999999957
#          Particles detected: [30.]
#          Mean x of the beam: [0.04660978] +/- [0.00180485]
#          X Variances of the beam: [3.25747173e-06]
# ZS_exit.monitor
#          Monitor position s: 20.304999999999517
#          Particles detected: [30.]
#          Mean x of the beam: [0.04624672] +/- [0.00178106]
#          X Variances of the beam: [3.17218135e-06]
# ZS_outside_1.monitor
#          Monitor position s: 20.924999999999635
#          Particles detected: [30.]
#          Mean x of the beam: [0.04552059] +/- [0.00173351]
#          X Variances of the beam: [3.00505336e-06]
# ZS_outside_2.monitor
#          Monitor position s: 24.644999999999662
#          Particles detected: [30.]
#          Mean x of the beam: [0.04116383] +/- [0.00144878]
#          X Variances of the beam: [2.09896351e-06]
# ZS_outside_3.monitor
#          Monitor position s: 28.364999999999558
#          Particles detected: [30.]
#          Mean x of the beam: [0.03756475] +/- [0.00119052]
#          X Variances of the beam: [1.41734953e-06]
# ZS_outside_4.monitor
#          Monitor position s: 32.084999999999646
#          Particles detected: [30.]
#          Mean x of the beam: [0.03871195] +/- [0.00108512]
#          X Variances of the beam: [1.17748943e-06]
# ZS_outside_5.monitor
#          Monitor position s: 35.80499999999949
#          Particles detected: [30.]
#          Mean x of the beam: [0.04171188] +/- [0.00100982]
#          X Variances of the beam: [1.01973513e-06]
# ZS_outside_6.monitor
#          Monitor position s: 39.524999999999515
#          Particles detected: [30.]
#          Mean x of the beam: [0.04472532] +/- [0.00093888]
#          X Variances of the beam: [8.81504353e-07]
# tpst.21760_0.monitor
#          Monitor position s: 43.24269999999944
#          Particles detected: [30.]
#          Mean x of the beam: [0.04773689] +/- [0.00087342]
#          X Variances of the beam: [7.62864215e-07]
# ZS_outside_7.monitor
#          Monitor position s: 43.24499999999954
#          Particles detected: [30.]
#          Mean x of the beam: [0.04773875] +/- [0.00087338]
#          X Variances of the beam: [7.62796852e-07]
# tpst.21760_1.monitor
#          Monitor position s: 43.48269999999945
#          Particles detected: [30.]
#          Mean x of the beam: [0.04793131] +/- [0.00086941]
#          X Variances of the beam: [7.55875302e-07]
# tpst.21760_2.monitor
#          Monitor position s: 43.722699999999456
#          Particles detected: [30.]
#          Mean x of the beam: [0.04812572] +/- [0.00086543]
#          X Variances of the beam: [7.48967652e-07]
# tpst.21760_3.monitor
#          Monitor position s: 43.962699999999465
#          Particles detected: [30.]
#          Mean x of the beam: [0.04832014] +/- [0.00086148]
#          X Variances of the beam: [7.42141264e-07]
# tpst.21760_4.monitor
#          Monitor position s: 44.202699999999474
#          Particles detected: [30.]
#          Mean x of the beam: [0.04851455] +/- [0.00085755]
#          X Variances of the beam: [7.35396138e-07]
# tpst.21760_5.monitor
#          Monitor position s: 44.44269999999948
#          Particles detected: [30.]
#          Mean x of the beam: [0.04870897] +/- [0.00085366]
#          X Variances of the beam: [7.28732275e-07]
# tpst.21760_6.monitor
#          Monitor position s: 44.68269999999949
#          Particles detected: [30.]
#          Mean x of the beam: [0.04890338] +/- [0.00084979]
#          X Variances of the beam: [7.22149673e-07]
# tpst.21760_7.monitor
#          Monitor position s: 44.9226999999995
#          Particles detected: [30.]
#          Mean x of the beam: [0.0490978] +/- [0.00084596]
#          X Variances of the beam: [7.15648335e-07]
# tpst.21760_8.monitor
#          Monitor position s: 45.16269999999951
#          Particles detected: [30.]
#          Mean x of the beam: [0.04929221] +/- [0.00084216]
#          X Variances of the beam: [7.09228258e-07]
# tpst.21760_9.monitor
#          Monitor position s: 45.40269999999952
#          Particles detected: [30.]
#          Mean x of the beam: [0.04948663] +/- [0.00083839]
#          X Variances of the beam: [7.02889444e-07]
# mst.21774_0.monitor
#          Monitor position s: 47.37569999999921
#          Particles detected: [30.]
#          Mean x of the beam: [0.05108488] +/- [0.00080862]
#          X Variances of the beam: [6.53859073e-07]
# mst.21774_1.monitor
#          Monitor position s: 47.61569999999922
#          Particles detected: [30.]
#          Mean x of the beam: [0.05129286] +/- [0.00080515]
#          X Variances of the beam: [6.48269538e-07]
# mst.21774_2.monitor
#          Monitor position s: 47.85569999999923
#          Particles detected: [30.]
#          Mean x of the beam: [0.0515144] +/- [0.00080172]
#          X Variances of the beam: [6.42761227e-07]
# mst.21774_3.monitor
#          Monitor position s: 48.09569999999924
#          Particles detected: [30.]
#          Mean x of the beam: [0.0517495] +/- [0.00079833]
#          X Variances of the beam: [6.37334127e-07]
# mst.21774_4.monitor
#          Monitor position s: 48.33569999999925
#          Particles detected: [30.]
#          Mean x of the beam: [0.05199816] +/- [0.00079498]
#          X Variances of the beam: [6.31988225e-07]
# mst.21774_5.monitor
#          Monitor position s: 48.5756999999992
#          Particles detected: [30.]
#          Mean x of the beam: [0.05226038] +/- [0.00079166]
#          X Variances of the beam: [6.2672351e-07]
# mst.21774_6.monitor
#          Monitor position s: 48.81569999999921
#          Particles detected: [30.]
#          Mean x of the beam: [0.05253616] +/- [0.00078838]
#          X Variances of the beam: [6.21539969e-07]
# mst.21774_7.monitor
#          Monitor position s: 49.05569999999922
#          Particles detected: [30.]
#          Mean x of the beam: [0.0528255] +/- [0.00078514]
#          X Variances of the beam: [6.16437591e-07]
# mst.21774_8.monitor
#          Monitor position s: 49.29569999999923
#          Particles detected: [30.]
#          Mean x of the beam: [0.0531284] +/- [0.00078193]
#          X Variances of the beam: [6.11416363e-07]
# mst.21774_9.monitor
#          Monitor position s: 49.53569999999924
#          Particles detected: [30.]
#          Mean x of the beam: [0.05344487] +/- [0.00077877]
#          X Variances of the beam: [6.06476273e-07]
# mst.21779_0.monitor
#          Monitor position s: 50.60969999999902
#          Particles detected: [30.]
#          Mean x of the beam: [0.05492173] +/- [0.00076509]
#          X Variances of the beam: [5.85363618e-07]
# mst.21779_1.monitor
#          Monitor position s: 50.84969999999903
#          Particles detected: [30.]
#          Mean x of the beam: [0.05526531] +/- [0.00076215]
#          X Variances of the beam: [5.80867859e-07]
# mst.21779_2.monitor
#          Monitor position s: 51.08969999999904
#          Particles detected: [30.]
#          Mean x of the beam: [0.05562246] +/- [0.00075925]
#          X Variances of the beam: [5.76453186e-07]
# mst.21779_3.monitor
#          Monitor position s: 51.32969999999905
#          Particles detected: [30.]
#          Mean x of the beam: [0.05599317] +/- [0.00075639]
#          X Variances of the beam: [5.7211959e-07]
# mst.21779_4.monitor
#          Monitor position s: 51.56969999999906
#          Particles detected: [30.]
#          Mean x of the beam: [0.05637744] +/- [0.00075357]
#          X Variances of the beam: [5.67867056e-07]
# mst.21779_5.monitor
#          Monitor position s: 51.80969999999901
#          Particles detected: [30.]
#          Mean x of the beam: [0.05677527] +/- [0.0007508]
#          X Variances of the beam: [5.63695573e-07]
# mst.21779_6.monitor
#          Monitor position s: 52.04969999999902
#          Particles detected: [30.]
#          Mean x of the beam: [0.05718666] +/- [0.00074807]
#          X Variances of the beam: [5.5960513e-07]
# mst.21779_7.monitor
#          Monitor position s: 52.28969999999903
#          Particles detected: [30.]
#          Mean x of the beam: [0.05761161] +/- [0.00074538]
#          X Variances of the beam: [5.55595713e-07]
# mst.21779_8.monitor
#          Monitor position s: 52.52969999999904
#          Particles detected: [30.]
#          Mean x of the beam: [0.05805012] +/- [0.00074274]
#          X Variances of the beam: [5.5166731e-07]
# mst.21779_9.monitor
#          Monitor position s: 52.76969999999905
#          Particles detected: [30.]
#          Mean x of the beam: [0.05850219] +/- [0.00074015]
#          X Variances of the beam: [5.4781991e-07]
# MST_outside_0.monitor
#          Monitor position s: 53.84369999999906
#          Particles detected: [30.]
#          Mean x of the beam: [0.06058591] +/- [0.00072911]
#          X Variances of the beam: [5.31595807e-07]
# mst.21794_0.monitor
#          Monitor position s: 53.84369999999906
#          Particles detected: [30.]
#          Mean x of the beam: [0.06058591] +/- [0.00072911]
#          X Variances of the beam: [5.31595807e-07]
# mst.21794_1.monitor
#          Monitor position s: 54.08369999999907
#          Particles detected: [30.]
#          Mean x of the beam: [0.0610651] +/- [0.00072677]
#          X Variances of the beam: [5.28192185e-07]
# mst.21794_2.monitor
#          Monitor position s: 54.32369999999908
#          Particles detected: [30.]
#          Mean x of the beam: [0.06155786] +/- [0.00072448]
#          X Variances of the beam: [5.24869515e-07]
# mst.21794_3.monitor
#          Monitor position s: 54.56369999999909
#          Particles detected: [30.]
#          Mean x of the beam: [0.06206418] +/- [0.00072224]
#          X Variances of the beam: [5.21627784e-07]
# mst.21794_4.monitor
#          Monitor position s: 54.8036999999991
#          Particles detected: [30.]
#          Mean x of the beam: [0.06258406] +/- [0.00072005]
#          X Variances of the beam: [5.18466982e-07]
# mst.21794_5.monitor
#          Monitor position s: 55.04369999999905
#          Particles detected: [30.]
#          Mean x of the beam: [0.0631175] +/- [0.0007179]
#          X Variances of the beam: [5.15387095e-07]
# mst.21794_6.monitor
#          Monitor position s: 55.28369999999906
#          Particles detected: [30.]
#          Mean x of the beam: [0.0636645] +/- [0.00071581]
#          X Variances of the beam: [5.12388111e-07]
# mst.21794_7.monitor
#          Monitor position s: 55.52369999999907
#          Particles detected: [30.]
#          Mean x of the beam: [0.06422506] +/- [0.00071377]
#          X Variances of the beam: [5.09470018e-07]
# mst.21794_8.monitor
#          Monitor position s: 55.763699999999076
#          Particles detected: [30.]
#          Mean x of the beam: [0.06479918] +/- [0.00071178]
#          X Variances of the beam: [5.06632805e-07]
# mst.21794_9.monitor
#          Monitor position s: 56.003699999999085
#          Particles detected: [30.]
#          Mean x of the beam: [0.06538686] +/- [0.00070984]
#          X Variances of the beam: [5.03876458e-07]
# MST_exit.monitor
#          Monitor position s: 56.243699999999095
#          Particles detected: [30.]
#          Mean x of the beam: [0.06598811] +/- [0.00070796]
#          X Variances of the beam: [5.01200966e-07]
# MST_outside_1.monitor
#          Monitor position s: 56.72369999999922
#          Particles detected: [30.]
#          Mean x of the beam: [0.0671906] +/- [0.00070434]
#          X Variances of the beam: [4.96093041e-07]
# MST_outside.monitor
#          Monitor position s: 58.643699999999036
#          Particles detected: [30.]
#          Mean x of the beam: [0.07199639] +/- [0.00069199]
#          X Variances of the beam: [4.78846645e-07]
# MST_outside_2.monitor
#          Monitor position s: 59.60369999999907
#          Particles detected: [30.]
#          Mean x of the beam: [0.07391815] +/- [0.00068258]
#          X Variances of the beam: [4.65913897e-07]
# MST_outside_3.monitor
#          Monitor position s: 62.48369999999924
#          Particles detected: [30.]
#          Mean x of the beam: [0.07475526] +/- [0.00061599]
#          X Variances of the beam: [3.79447702e-07]
# mse.21832_0.monitor
#          Monitor position s: 64.82839999999884
#          Particles detected: [30.]
#          Mean x of the beam: [0.07269761] +/- [0.00054674]
#          X Variances of the beam: [2.98926396e-07]
# mse.21832_1.monitor
#          Monitor position s: 65.0563999999989
#          Particles detected: [30.]
#          Mean x of the beam: [0.07254196] +/- [0.00054053]
#          X Variances of the beam: [2.9217452e-07]
# mse.21832_2.monitor
#          Monitor position s: 65.28439999999874
#          Particles detected: [30.]
#          Mean x of the beam: [0.07243074] +/- [0.00053443]
#          X Variances of the beam: [2.85612979e-07]
# mse.21832_3.monitor
#          Monitor position s: 65.5123999999988
#          Particles detected: [30.]
#          Mean x of the beam: [0.07236396] +/- [0.00052843]
#          X Variances of the beam: [2.79241757e-07]
# mse.21832_4.monitor
#          Monitor position s: 65.74039999999887
#          Particles detected: [30.]
#          Mean x of the beam: [0.07234162] +/- [0.00052255]
#          X Variances of the beam: [2.73060841e-07]
# mse.21832_5.monitor
#          Monitor position s: 65.96839999999894
#          Particles detected: [30.]
#          Mean x of the beam: [0.07236371] +/- [0.00051679]
#          X Variances of the beam: [2.67070218e-07]
# mse.21832_6.monitor
#          Monitor position s: 66.19639999999872
#          Particles detected: [30.]
#          Mean x of the beam: [0.07243024] +/- [0.00051115]
#          X Variances of the beam: [2.61269874e-07]
# mse.21832_7.monitor
#          Monitor position s: 66.42439999999878
#          Particles detected: [30.]
#          Mean x of the beam: [0.0725412] +/- [0.00050563]
#          X Variances of the beam: [2.55659795e-07]
# mse.21832_8.monitor
#          Monitor position s: 66.65239999999885
#          Particles detected: [30.]
#          Mean x of the beam: [0.0726966] +/- [0.00050024]
#          X Variances of the beam: [2.50239968e-07]
# mse.21832_9.monitor
#          Monitor position s: 66.88039999999869
#          Particles detected: [30.]
#          Mean x of the beam: [0.07289644] +/- [0.00049499]
#          X Variances of the beam: [2.45010377e-07]
# mse.21837_0.monitor
#          Monitor position s: 68.06239999999865
#          Particles detected: [30.]
#          Mean x of the beam: [0.07416279] +/- [0.00047006]
#          X Variances of the beam: [2.20958424e-07]
# mse.21837_1.monitor
#          Monitor position s: 68.29039999999871
#          Particles detected: [30.]
#          Mean x of the beam: [0.0744515] +/- [0.00046573]
#          X Variances of the beam: [2.16909055e-07]
# mse.21837_2.monitor
#          Monitor position s: 68.51839999999855
#          Particles detected: [30.]
#          Mean x of the beam: [0.07478464] +/- [0.00046157]
#          X Variances of the beam: [2.13049864e-07]
# mse.21837_3.monitor
#          Monitor position s: 68.74639999999862
#          Particles detected: [30.]
#          Mean x of the beam: [0.07516222] +/- [0.00045758]
#          X Variances of the beam: [2.09380836e-07]
# mse.21837_4.monitor
#          Monitor position s: 68.97439999999868
#          Particles detected: [30.]
#          Mean x of the beam: [0.07558423] +/- [0.00045376]
#          X Variances of the beam: [2.05901958e-07]
# mse.21837_5.monitor
#          Monitor position s: 69.20239999999875
#          Particles detected: [30.]
#          Mean x of the beam: [0.07605068] +/- [0.00045013]
#          X Variances of the beam: [2.02613217e-07]
# mse.21837_6.monitor
#          Monitor position s: 69.43039999999853
#          Particles detected: [30.]
#          Mean x of the beam: [0.07656157] +/- [0.00044667]
#          X Variances of the beam: [1.99514599e-07]
# mse.21837_7.monitor
#          Monitor position s: 69.6583999999986
#          Particles detected: [30.]
#          Mean x of the beam: [0.07711689] +/- [0.0004434]
#          X Variances of the beam: [1.96606089e-07]
# mse.21837_8.monitor
#          Monitor position s: 69.88639999999866
#          Particles detected: [30.]
#          Mean x of the beam: [0.07771665] +/- [0.00044033]
#          X Variances of the beam: [1.93887675e-07]
# mse.21837_9.monitor
#          Monitor position s: 70.1143999999985
#          Particles detected: [30.]
#          Mean x of the beam: [0.07836084] +/- [0.00043745]
#          X Variances of the beam: [1.91359343e-07]
# mse.21852_0.monitor
#          Monitor position s: 71.29639999999846
#          Particles detected: [30.]
#          Mean x of the beam: [0.08193084] +/- [0.0004258]
#          X Variances of the beam: [1.81309487e-07]
# mse.21852_1.monitor
#          Monitor position s: 71.52439999999852
#          Particles detected: [30.]
#          Mean x of the beam: [0.08266391] +/- [0.00042422]
#          X Variances of the beam: [1.79960685e-07]
# mse.21852_2.monitor
#          Monitor position s: 71.75239999999836
#          Particles detected: [30.]
#          Mean x of the beam: [0.08344141] +/- [0.00042285]
#          X Variances of the beam: [1.78801904e-07]
# mse.21852_3.monitor
#          Monitor position s: 71.98039999999843
#          Particles detected: [30.]
#          Mean x of the beam: [0.08426335] +/- [0.0004217]
#          X Variances of the beam: [1.77833133e-07]
# mse.21852_4.monitor
#          Monitor position s: 72.20839999999849
#          Particles detected: [30.]
#          Mean x of the beam: [0.08512972] +/- [0.00042078]
#          X Variances of the beam: [1.77054356e-07]
# mse.21852_5.monitor
#          Monitor position s: 72.43639999999856
#          Particles detected: [30.]
#          Mean x of the beam: [0.08604053] +/- [0.00042008]
#          X Variances of the beam: [1.7646556e-07]
# mse.21852_6.monitor
#          Monitor position s: 72.66439999999834
#          Particles detected: [30.]
#          Mean x of the beam: [0.08699577] +/- [0.0004196]
#          X Variances of the beam: [1.76066733e-07]
# mse.21852_7.monitor
#          Monitor position s: 72.8923999999984
#          Particles detected: [30.]
#          Mean x of the beam: [0.08799545] +/- [0.00041935]
#          X Variances of the beam: [1.75857859e-07]
# mse.21852_8.monitor
#          Monitor position s: 73.12039999999847
#          Particles detected: [30.]
#          Mean x of the beam: [0.08903957] +/- [0.00041933]
#          X Variances of the beam: [1.75838927e-07]
# mse.21852_9.monitor
#          Monitor position s: 73.3483999999983
#          Particles detected: [30.]
#          Mean x of the beam: [0.09012812] +/- [0.00041954]
#          X Variances of the beam: [1.76009921e-07]
# mse.21857_0.monitor
#          Monitor position s: 74.5303999999985
#          Particles detected: [30.]
#          Mean x of the beam: [0.09600176] +/- [0.00042421]
#          X Variances of the beam: [1.79952162e-07]
# mse.21857_1.monitor
#          Monitor position s: 74.75839999999856
#          Particles detected: [30.]
#          Mean x of the beam: [0.09717919] +/- [0.0004258]
#          X Variances of the beam: [1.81302e-07]
# mse.21857_2.monitor
#          Monitor position s: 74.9863999999984
#          Particles detected: [30.]
#          Mean x of the beam: [0.09840105] +/- [0.0004276]
#          X Variances of the beam: [1.82841705e-07]
# mse.21857_3.monitor
#          Monitor position s: 75.21439999999846
#          Particles detected: [30.]
#          Mean x of the beam: [0.09966734] +/- [0.00042962]
#          X Variances of the beam: [1.84571265e-07]
# mse.21857_4.monitor
#          Monitor position s: 75.44239999999853
#          Particles detected: [30.]
#          Mean x of the beam: [0.10097807] +/- [0.00043185]
#          X Variances of the beam: [1.86490666e-07]
# mse.21857_5.monitor
#          Monitor position s: 75.6703999999986
#          Particles detected: [30.]
#          Mean x of the beam: [0.10233324] +/- [0.00043428]
#          X Variances of the beam: [1.88599894e-07]
# mse.21857_6.monitor
#          Monitor position s: 75.89839999999838
#          Particles detected: [30.]
#          Mean x of the beam: [0.10373284] +/- [0.00043692]
#          X Variances of the beam: [1.90898937e-07]
# mse.21857_7.monitor
#          Monitor position s: 76.12639999999844
#          Particles detected: [30.]
#          Mean x of the beam: [0.10517688] +/- [0.00043976]
#          X Variances of the beam: [1.9338778e-07]
# mse.21857_8.monitor
#          Monitor position s: 76.3543999999985
#          Particles detected: [30.]
#          Mean x of the beam: [0.10666535] +/- [0.00044279]
#          X Variances of the beam: [1.9606641e-07]
# mse.21857_9.monitor
#          Monitor position s: 76.58239999999834
#          Particles detected: [30.]
#          Mean x of the beam: [0.10819826] +/- [0.00044602]
#          X Variances of the beam: [1.98934814e-07]
# MSE_outside_0.monitor
#          Monitor position s: 77.7643999999983
#          Particles detected: [30.]
#          Mean x of the beam: [0.11637555] +/- [0.00046568]
#          X Variances of the beam: [2.16859224e-07]
# mse.21872_0.monitor
#          Monitor position s: 77.7643999999983
#          Particles detected: [30.]
#          Mean x of the beam: [0.11637555] +/- [0.00046568]
#          X Variances of the beam: [2.16859224e-07]
# mse.21872_1.monitor
#          Monitor position s: 77.99239999999837
#          Particles detected: [30.]
#          Mean x of the beam: [0.11799733] +/- [0.00047001]
#          X Variances of the beam: [2.20905789e-07]
# mse.21872_2.monitor
#          Monitor position s: 78.22039999999821
#          Particles detected: [30.]
#          Mean x of the beam: [0.11966355] +/- [0.00047449]
#          X Variances of the beam: [2.25142068e-07]
# mse.21872_3.monitor
#          Monitor position s: 78.44839999999827
#          Particles detected: [30.]
#          Mean x of the beam: [0.1213742] +/- [0.00047913]
#          X Variances of the beam: [2.29568049e-07]
# mse.21872_4.monitor
#          Monitor position s: 78.67639999999834
#          Particles detected: [30.]
#          Mean x of the beam: [0.12312929] +/- [0.00048393]
#          X Variances of the beam: [2.34183719e-07]
# mse.21872_5.monitor
#          Monitor position s: 78.9043999999984
#          Particles detected: [30.]
#          Mean x of the beam: [0.12492882] +/- [0.00048887]
#          X Variances of the beam: [2.38989063e-07]
# mse.21872_6.monitor
#          Monitor position s: 79.13239999999819
#          Particles detected: [30.]
#          Mean x of the beam: [0.12677278] +/- [0.00049395]
#          X Variances of the beam: [2.43984068e-07]
# mse.21872_7.monitor
#          Monitor position s: 79.36039999999825
#          Particles detected: [30.]
#          Mean x of the beam: [0.12866117] +/- [0.00049917]
#          X Variances of the beam: [2.49168721e-07]
# mse.21872_8.monitor
#          Monitor position s: 79.58839999999832
#          Particles detected: [30.]
#          Mean x of the beam: [0.13059401] +/- [0.00050452]
#          X Variances of the beam: [2.5454301e-07]
# mse.21872_9.monitor
#          Monitor position s: 79.81639999999815
#          Particles detected: [30.]
#          Mean x of the beam: [0.13257127] +/- [0.00051001]
#          X Variances of the beam: [2.60106919e-07]
# MSE_exit.monitor
#          Monitor position s: 80.04439999999822
#          Particles detected: [30.]
#          Mean x of the beam: [0.13459298] +/- [0.00051562]
#          X Variances of the beam: [2.65860437e-07]
# MSE_outside_1.monitor
#          Monitor position s: 81.18439999999843
#          Particles detected: [30.]
#          Mean x of the beam: [0.1447015] +/- [0.00054543]
#          X Variances of the beam: [2.97489854e-07]
# MSE_outside_2.monitor
#          Monitor position s: 84.60439999999822
#          Particles detected: [30.]
#          Mean x of the beam: [0.17502705] +/- [0.00064884]
#          X Variances of the beam: [4.20996401e-07]
# MSE_outside_3.monitor
#          Monitor position s: 88.0243999999983
#          Particles detected: [30.]
#          Mean x of the beam: [0.2053526] +/- [0.00076644]
#          X Variances of the beam: [5.87430392e-07]
# MSE_outside_4.monitor
#          Monitor position s: 91.44439999999841
#          Particles detected: [30.]
#          Mean x of the beam: [0.23679839] +/- [0.00089684]
#          X Variances of the beam: [8.04326634e-07]
# MSE_outside_5.monitor
#          Monitor position s: 94.86439999999831
#          Particles detected: [30.]
#          Mean x of the beam: [0.29287559] +/- [0.00112567]
#          X Variances of the beam: [1.26712749e-06]
# MSE_outside_6.monitor
#          Monitor position s: 98.28439999999833
#          Particles detected: [30.]
#          Mean x of the beam: [0.36218292] +/- [0.00140767]
#          X Variances of the beam: [1.98152097e-06]
# MSE_outside_7.monitor
#          Monitor position s: 101.7043999999984
#          Particles detected: [30.]
#          Mean x of the beam: [0.43149026] +/- [0.00169111]
#          X Variances of the beam: [2.8598692e-06]

# %%
s_positions_monitors = []
x_means = []
x_stds = []

for i, monitor_name in enumerate(LSS2.element_names):
    if "monitor" in monitor_name:
        monitor = LSS2.element_dict[monitor_name]
        
        # Positions of the monitors
        s_position = LSS2.get_s_position(monitor_name)
        s_positions_monitors.append(s_position)
        
# Mean x and x_std arrays
        try:
            # Assicurati che x_mean e x_std siano scalari
            x_mean = np.mean(monitor.x_mean) if np.ndim(monitor.x_mean) > 0 else monitor.x_mean
            x_std = np.mean(monitor.x_std) if np.ndim(monitor.x_std) > 0 else monitor.x_std
            
            x_means.append(x_mean)
            x_stds.append(x_std)
        except AttributeError:
            print(f"Monitor {monitor_name} non contiene dati validi.")

# Converting the lists in  numpy arrays
s_positions_monitors = np.array(s_positions_monitors)
x_means = np.array(x_means)
x_stds = np.array(x_stds)

# %%
# Drawing the elements
fig, ax = plt.subplots(figsize=(10, 6))

ax.set_ylim(-0.1, 0.25)
ax.set_xlim(1, 90)
draw_sep_elements(ax, LSS2)

up_beam_position = x_means + x_stds
down_beam_position = x_means - x_stds

max_beam_position = x_means + 3 * x_stds
min_beam_position = x_means - 3 * x_stds 

ax.plot(s_positions_monitors, down_beam_position, color = 'grey', linestyle='-')
ax.plot(s_positions_monitors, up_beam_position, color = 'grey', linestyle='-')
#ax.plot(s_positions_monitors, max_beam_position, color = 'grey', linestyle='-')
#ax.plot(s_positions_monitors, min_beam_position, color = 'grey', linestyle='-')

ax.plot(x_min, color = 'red', linestyle=':', label = 'X min and max of extracted beam')
ax.plot(x_max,  color = 'red', linestyle=':')

ax.plot(x_minInitial, color = 'blue', linestyle='-', label = 'Circulating beam')
ax.plot(x_maxInitial,  color = 'blue', linestyle='-')

ax.grid(True)

ax.fill_between(s_positions_monitors,  down_beam_position, up_beam_position, color='blue', alpha=0.2, label = 'X  mean +/- 1 sigma')
#ax.fill_between(s_positions_monitors,  max_beam_position, min_beam_position, color='red', alpha=0.2, label = 'X  mean +/- 3 sigma')

ax.legend(title = "Beam's envelope", loc =  'lower right')
# Out:
# Element: zs.21633_0.sep, s_position: 1.565, blade_position: 0.068, thickness: 6e-05
# Element: zs.21633_1.sep, s_position: 1.8749999999999454, blade_position: 0.06753350000000001, thickness: 6e-05
# Element: zs.21633_2.sep, s_position: 2.184999999999891, blade_position: 0.067067, thickness: 6e-05
# Element: zs.21633_3.sep, s_position: 2.4950000000000636, blade_position: 0.0666005, thickness: 6e-05
# Element: zs.21633_4.sep, s_position: 2.805000000000009, blade_position: 0.066134, thickness: 6e-05
# Element: zs.21633_5.sep, s_position: 3.1149999999999545, blade_position: 0.0656675, thickness: 6e-05
# Element: zs.21633_6.sep, s_position: 3.4249999999998453, blade_position: 0.06520100000000001, thickness: 6e-05
# Element: zs.21633_7.sep, s_position: 3.735000000000018, blade_position: 0.0647345, thickness: 6e-05
# Element: zs.21633_8.sep, s_position: 4.0449999999999635, blade_position: 0.064268, thickness: 6e-05
# Element: zs.21633_9.sep, s_position: 4.354999999999909, blade_position: 0.06380150000000001, thickness: 6e-05
# Element: zs.21639_0.sep, s_position: 5.474999999999973, blade_position: 0.06212, thickness: 6e-05
# Element: zs.21639_1.sep, s_position: 5.784999999999918, blade_position: 0.0616535, thickness: 6e-05
# Element: zs.21639_2.sep, s_position: 6.094999999999864, blade_position: 0.061187, thickness: 6e-05
# Element: zs.21639_3.sep, s_position: 6.405000000000037, blade_position: 0.060720500000000004, thickness: 6e-05
# Element: zs.21639_4.sep, s_position: 6.714999999999982, blade_position: 0.060254, thickness: 6e-05
# Element: zs.21639_5.sep, s_position: 7.0249999999999275, blade_position: 0.0597875, thickness: 6e-05
# Element: zs.21639_6.sep, s_position: 7.334999999999818, blade_position: 0.059321, thickness: 6e-05
# Element: zs.21639_7.sep, s_position: 7.644999999999991, blade_position: 0.058854500000000004, thickness: 6e-05
# Element: zs.21639_8.sep, s_position: 7.954999999999936, blade_position: 0.058388, thickness: 6e-05
# Element: zs.21639_9.sep, s_position: 8.264999999999882, blade_position: 0.0579215, thickness: 6e-05
# Element: zs.21655_0.sep, s_position: 9.384999999999717, blade_position: 0.05623, thickness: 0.0001
# Element: zs.21655_1.sep, s_position: 9.694999999999663, blade_position: 0.0557635, thickness: 0.0001
# Element: zs.21655_2.sep, s_position: 10.004999999999608, blade_position: 0.055297, thickness: 0.0001
# Element: zs.21655_3.sep, s_position: 10.314999999999781, blade_position: 0.054830500000000004, thickness: 0.0001
# Element: zs.21655_4.sep, s_position: 10.624999999999726, blade_position: 0.054364, thickness: 0.0001
# Element: zs.21655_5.sep, s_position: 10.934999999999672, blade_position: 0.0538975, thickness: 0.0001
# Element: zs.21655_6.sep, s_position: 11.244999999999562, blade_position: 0.053431, thickness: 0.0001
# Element: zs.21655_7.sep, s_position: 11.554999999999735, blade_position: 0.052964500000000005, thickness: 0.0001
# Element: zs.21655_8.sep, s_position: 11.86499999999968, blade_position: 0.052498, thickness: 0.0001
# Element: zs.21655_9.sep, s_position: 12.174999999999626, blade_position: 0.0520315, thickness: 0.0001
# Element: zs.21671_0.sep, s_position: 13.294999999999689, blade_position: 0.05035, thickness: 0.0001
# Element: zs.21671_1.sep, s_position: 13.604999999999634, blade_position: 0.0498835, thickness: 0.0001
# Element: zs.21671_2.sep, s_position: 13.91499999999958, blade_position: 0.049416999999999996, thickness: 0.0001
# Element: zs.21671_3.sep, s_position: 14.224999999999753, blade_position: 0.0489505, thickness: 0.0001
# Element: zs.21671_4.sep, s_position: 14.534999999999698, blade_position: 0.048484, thickness: 0.0001
# Element: zs.21671_5.sep, s_position: 14.844999999999644, blade_position: 0.0480175, thickness: 0.0001
# Element: zs.21671_6.sep, s_position: 15.154999999999534, blade_position: 0.047550999999999996, thickness: 0.0001
# Element: zs.21671_7.sep, s_position: 15.464999999999707, blade_position: 0.0470845, thickness: 0.0001
# Element: zs.21671_8.sep, s_position: 15.774999999999652, blade_position: 0.046618, thickness: 0.0001
# Element: zs.21671_9.sep, s_position: 16.084999999999596, blade_position: 0.0461515, thickness: 0.0001
# Element: zs.21676_0.sep, s_position: 17.20499999999966, blade_position: 0.04446, thickness: 0.0001
# Element: zs.21676_1.sep, s_position: 17.514999999999606, blade_position: 0.0439935, thickness: 0.0001
# Element: zs.21676_2.sep, s_position: 17.82499999999955, blade_position: 0.043526999999999996, thickness: 0.0001
# Element: zs.21676_3.sep, s_position: 18.134999999999724, blade_position: 0.0430605, thickness: 0.0001
# Element: zs.21676_4.sep, s_position: 18.44499999999967, blade_position: 0.042594, thickness: 0.0001
# Element: zs.21676_5.sep, s_position: 18.754999999999615, blade_position: 0.0421275, thickness: 0.0001
# Element: zs.21676_6.sep, s_position: 19.064999999999507, blade_position: 0.041661, thickness: 0.0001
# Element: zs.21676_7.sep, s_position: 19.37499999999968, blade_position: 0.0411945, thickness: 0.0001
# Element: zs.21676_8.sep, s_position: 19.684999999999626, blade_position: 0.040728, thickness: 0.0001
# Element: zs.21676_9.sep, s_position: 19.99499999999957, blade_position: 0.0402615, thickness: 0.0001
# Element: tpst.21760_0.sep, s_position: 43.24269999999944, blade_position: 0.04, thickness: 0.0042
# Element: tpst.21760_1.sep, s_position: 43.48269999999945, blade_position: 0.040106, thickness: 0.0042
# Element: tpst.21760_2.sep, s_position: 43.722699999999456, blade_position: 0.040212, thickness: 0.0042
# Element: tpst.21760_3.sep, s_position: 43.962699999999465, blade_position: 0.040318, thickness: 0.0042
# Element: tpst.21760_4.sep, s_position: 44.202699999999474, blade_position: 0.040424, thickness: 0.0042
# Element: tpst.21760_5.sep, s_position: 44.44269999999948, blade_position: 0.040530000000000004, thickness: 0.0042
# Element: tpst.21760_6.sep, s_position: 44.68269999999949, blade_position: 0.040636, thickness: 0.0042
# Element: tpst.21760_7.sep, s_position: 44.9226999999995, blade_position: 0.040742, thickness: 0.0042
# Element: tpst.21760_8.sep, s_position: 45.16269999999951, blade_position: 0.040848, thickness: 0.0042
# Element: tpst.21760_9.sep, s_position: 45.40269999999952, blade_position: 0.040954000000000004, thickness: 0.0042
# Element: mst.21774_0.sep, s_position: 47.37569999999921, blade_position: 0.04079, thickness: 0.0042
# Element: mst.21774_1.sep, s_position: 47.61569999999922, blade_position: 0.040909, thickness: 0.0042
# Element: mst.21774_2.sep, s_position: 47.85569999999923, blade_position: 0.041028, thickness: 0.0042
# Element: mst.21774_3.sep, s_position: 48.09569999999924, blade_position: 0.041147, thickness: 0.0042
# Element: mst.21774_4.sep, s_position: 48.33569999999925, blade_position: 0.041266, thickness: 0.0042
# Element: mst.21774_5.sep, s_position: 48.5756999999992, blade_position: 0.041385, thickness: 0.0042
# Element: mst.21774_6.sep, s_position: 48.81569999999921, blade_position: 0.041504, thickness: 0.0042
# Element: mst.21774_7.sep, s_position: 49.05569999999922, blade_position: 0.041623, thickness: 0.0042
# Element: mst.21774_8.sep, s_position: 49.29569999999923, blade_position: 0.041742, thickness: 0.0042
# Element: mst.21774_9.sep, s_position: 49.53569999999924, blade_position: 0.041861, thickness: 0.0042
# Element: mst.21779_0.sep, s_position: 50.60969999999902, blade_position: 0.0424, thickness: 0.0042
# Element: mst.21779_1.sep, s_position: 50.84969999999903, blade_position: 0.042519, thickness: 0.0042
# Element: mst.21779_2.sep, s_position: 51.08969999999904, blade_position: 0.042638, thickness: 0.0042
# Element: mst.21779_3.sep, s_position: 51.32969999999905, blade_position: 0.042757, thickness: 0.0042
# Element: mst.21779_4.sep, s_position: 51.56969999999906, blade_position: 0.042876, thickness: 0.0042
# Element: mst.21779_5.sep, s_position: 51.80969999999901, blade_position: 0.042995, thickness: 0.0042
# Element: mst.21779_6.sep, s_position: 52.04969999999902, blade_position: 0.043114, thickness: 0.0042
# Element: mst.21779_7.sep, s_position: 52.28969999999903, blade_position: 0.043233, thickness: 0.0042
# Element: mst.21779_8.sep, s_position: 52.52969999999904, blade_position: 0.043352, thickness: 0.0042
# Element: mst.21779_9.sep, s_position: 52.76969999999905, blade_position: 0.043471, thickness: 0.0042
# Element: mst.21794_0.sep, s_position: 53.84369999999906, blade_position: 0.04401, thickness: 0.0042
# Element: mst.21794_1.sep, s_position: 54.08369999999907, blade_position: 0.044129, thickness: 0.0042
# Element: mst.21794_2.sep, s_position: 54.32369999999908, blade_position: 0.044248, thickness: 0.0042
# Element: mst.21794_3.sep, s_position: 54.56369999999909, blade_position: 0.044367000000000004, thickness: 0.0042
# Element: mst.21794_4.sep, s_position: 54.8036999999991, blade_position: 0.044486, thickness: 0.0042
# Element: mst.21794_5.sep, s_position: 55.04369999999905, blade_position: 0.044605, thickness: 0.0042
# Element: mst.21794_6.sep, s_position: 55.28369999999906, blade_position: 0.044724, thickness: 0.0042
# Element: mst.21794_7.sep, s_position: 55.52369999999907, blade_position: 0.044843, thickness: 0.0042
# Element: mst.21794_8.sep, s_position: 55.763699999999076, blade_position: 0.044962, thickness: 0.0042
# Element: mst.21794_9.sep, s_position: 56.003699999999085, blade_position: 0.045081, thickness: 0.0042
# Element: mse.21832_0.sep, s_position: 64.82839999999884, blade_position: 0.0527, thickness: 0.01725
# Element: mse.21832_1.sep, s_position: 65.0563999999989, blade_position: 0.052597, thickness: 0.01725
# Element: mse.21832_2.sep, s_position: 65.28439999999874, blade_position: 0.052494, thickness: 0.01725
# Element: mse.21832_3.sep, s_position: 65.5123999999988, blade_position: 0.052391, thickness: 0.01725
# Element: mse.21832_4.sep, s_position: 65.74039999999887, blade_position: 0.052288, thickness: 0.01725
# Element: mse.21832_5.sep, s_position: 65.96839999999894, blade_position: 0.052184999999999995, thickness: 0.01725
# Element: mse.21832_6.sep, s_position: 66.19639999999872, blade_position: 0.052081999999999996, thickness: 0.01725
# Element: mse.21832_7.sep, s_position: 66.42439999999878, blade_position: 0.051979, thickness: 0.01725
# Element: mse.21832_8.sep, s_position: 66.65239999999885, blade_position: 0.051876, thickness: 0.01725
# Element: mse.21832_9.sep, s_position: 66.88039999999869, blade_position: 0.051773, thickness: 0.01725
# Element: mse.21837_0.sep, s_position: 68.06239999999865, blade_position: 0.05184, thickness: 0.01725
# Element: mse.21837_1.sep, s_position: 68.29039999999871, blade_position: 0.052028, thickness: 0.01725
# Element: mse.21837_2.sep, s_position: 68.51839999999855, blade_position: 0.052216, thickness: 0.01725
# Element: mse.21837_3.sep, s_position: 68.74639999999862, blade_position: 0.052404, thickness: 0.01725
# Element: mse.21837_4.sep, s_position: 68.97439999999868, blade_position: 0.052592, thickness: 0.01725
# Element: mse.21837_5.sep, s_position: 69.20239999999875, blade_position: 0.052779999999999994, thickness: 0.01725
# Element: mse.21837_6.sep, s_position: 69.43039999999853, blade_position: 0.052967999999999994, thickness: 0.01725
# Element: mse.21837_7.sep, s_position: 69.6583999999986, blade_position: 0.053155999999999995, thickness: 0.01725
# Element: mse.21837_8.sep, s_position: 69.88639999999866, blade_position: 0.053343999999999996, thickness: 0.01725
# Element: mse.21837_9.sep, s_position: 70.1143999999985, blade_position: 0.053531999999999996, thickness: 0.01725
# Element: mse.21852_0.sep, s_position: 71.29639999999846, blade_position: 0.05511, thickness: 0.01725
# Element: mse.21852_1.sep, s_position: 71.52439999999852, blade_position: 0.055588, thickness: 0.01725
# Element: mse.21852_2.sep, s_position: 71.75239999999836, blade_position: 0.056066, thickness: 0.01725
# Element: mse.21852_3.sep, s_position: 71.98039999999843, blade_position: 0.056544, thickness: 0.01725
# Element: mse.21852_4.sep, s_position: 72.20839999999849, blade_position: 0.057021999999999996, thickness: 0.01725
# Element: mse.21852_5.sep, s_position: 72.43639999999856, blade_position: 0.057499999999999996, thickness: 0.01725
# Element: mse.21852_6.sep, s_position: 72.66439999999834, blade_position: 0.057978, thickness: 0.01725
# Element: mse.21852_7.sep, s_position: 72.8923999999984, blade_position: 0.058456, thickness: 0.01725
# Element: mse.21852_8.sep, s_position: 73.12039999999847, blade_position: 0.058934, thickness: 0.01725
# Element: mse.21852_9.sep, s_position: 73.3483999999983, blade_position: 0.059412, thickness: 0.01725
# Element: mse.21857_0.sep, s_position: 74.5303999999985, blade_position: 0.0625, thickness: 0.01725
# Element: mse.21857_1.sep, s_position: 74.75839999999856, blade_position: 0.063269, thickness: 0.01725
# Element: mse.21857_2.sep, s_position: 74.9863999999984, blade_position: 0.064038, thickness: 0.01725
# Element: mse.21857_3.sep, s_position: 75.21439999999846, blade_position: 0.064807, thickness: 0.01725
# Element: mse.21857_4.sep, s_position: 75.44239999999853, blade_position: 0.065576, thickness: 0.01725
# Element: mse.21857_5.sep, s_position: 75.6703999999986, blade_position: 0.066345, thickness: 0.01725
# Element: mse.21857_6.sep, s_position: 75.89839999999838, blade_position: 0.06711400000000001, thickness: 0.01725
# Element: mse.21857_7.sep, s_position: 76.12639999999844, blade_position: 0.067883, thickness: 0.01725
# Element: mse.21857_8.sep, s_position: 76.3543999999985, blade_position: 0.068652, thickness: 0.01725
# Element: mse.21857_9.sep, s_position: 76.58239999999834, blade_position: 0.069421, thickness: 0.01725
# Element: mse.21872_0.sep, s_position: 77.7643999999983, blade_position: 0.074, thickness: 0.01725
# Element: mse.21872_1.sep, s_position: 77.99239999999837, blade_position: 0.07506, thickness: 0.01725
# Element: mse.21872_2.sep, s_position: 78.22039999999821, blade_position: 0.07612, thickness: 0.01725
# Element: mse.21872_3.sep, s_position: 78.44839999999827, blade_position: 0.07718, thickness: 0.01725
# Element: mse.21872_4.sep, s_position: 78.67639999999834, blade_position: 0.07823999999999999, thickness: 0.01725
# Element: mse.21872_5.sep, s_position: 78.9043999999984, blade_position: 0.0793, thickness: 0.01725
# Element: mse.21872_6.sep, s_position: 79.13239999999819, blade_position: 0.08036, thickness: 0.01725
# Element: mse.21872_7.sep, s_position: 79.36039999999825, blade_position: 0.08141999999999999, thickness: 0.01725
# Element: mse.21872_8.sep, s_position: 79.58839999999832, blade_position: 0.08248, thickness: 0.01725
# Element: mse.21872_9.sep, s_position: 79.81639999999815, blade_position: 0.08353999999999999, thickness: 0.01725
# /var/folders/vc/njn3rgb96cq7_32jmcfzppkm0000gn/T/ipykernel_55504/658899991.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')

# %%
fig2, ax2 = plt.subplots(figsize=(10, 6))

ax2.set_ylabel(r'Twiss (m)')
ax2.plot(twissDF['s'], twissDF['betx'], 'r-', label=r'$\beta_x$')
ax2.plot(twissDF['s'], twissDF['bety'], 'b-', label=r'$\beta_y$')
ax2.plot(twissDF['s'], twissDF['dx']*10, 'g-', label=r'$D_x x10$')
ax2.set_xlim(1, 90)
ax2.legend(loc='upper right')
plt.grid(True)

# %%
# Drawing the elements
#fig, (ax, ax2) = plt.subplots(figsize=(10, 6))
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True)

ax.set_ylim(0.0, 0.25)
ax.set_xlim(1, 90)
draw_sep_elements(ax, LSS2)

up_beam_position = x_means + x_stds
down_beam_position = x_means - x_stds

max_beam_position = x_means + 3 * x_stds
min_beam_position = x_means - 3 * x_stds 

ax.plot(s_positions_monitors, down_beam_position, color = 'grey', linestyle='-')
ax.plot(s_positions_monitors, up_beam_position, color = 'grey', linestyle='-')
ax.plot(s_positions_monitors, max_beam_position, color = 'grey', linestyle='-')
ax.plot(s_positions_monitors, min_beam_position, color = 'grey', linestyle='-')

ax.plot(x_min, color = 'red', linestyle=':', label = 'X min and max')
ax.plot(x_max,  color = 'red', linestyle=':')

ax.fill_between(s_positions_monitors,  down_beam_position, up_beam_position, color='blue', alpha=0.2, label = 'X  mean +/- 1 sigma')
ax.fill_between(s_positions_monitors,  max_beam_position, min_beam_position, color='red', alpha=0.2, label = 'X  mean +/- 3 sigma')

#ax.legend(title = "Beam's envelope")


ax2.set_ylabel(r'Twiss (m)')
ax2.plot(twissDF['s'], twissDF['betx'], 'r-', label=r'$\beta_x$')
ax2.plot(twissDF['s'], twissDF['bety'], 'b-', label=r'$\beta_y$')
ax2.plot(twissDF['s'], twissDF['dx']*10, 'g-', label=r'$D_x x10$')
ax2.set_xlim(1, 90)
ax2.legend(loc='upper right')
plt.grid(True)
# Out:
# Element: zs.21633_0.sep, s_position: 1.565, blade_position: 0.068, thickness: 6e-05
# Element: zs.21633_1.sep, s_position: 1.8749999999999454, blade_position: 0.06753350000000001, thickness: 6e-05
# Element: zs.21633_2.sep, s_position: 2.184999999999891, blade_position: 0.067067, thickness: 6e-05
# Element: zs.21633_3.sep, s_position: 2.4950000000000636, blade_position: 0.0666005, thickness: 6e-05
# Element: zs.21633_4.sep, s_position: 2.805000000000009, blade_position: 0.066134, thickness: 6e-05
# Element: zs.21633_5.sep, s_position: 3.1149999999999545, blade_position: 0.0656675, thickness: 6e-05
# Element: zs.21633_6.sep, s_position: 3.4249999999998453, blade_position: 0.06520100000000001, thickness: 6e-05
# Element: zs.21633_7.sep, s_position: 3.735000000000018, blade_position: 0.0647345, thickness: 6e-05
# Element: zs.21633_8.sep, s_position: 4.0449999999999635, blade_position: 0.064268, thickness: 6e-05
# Element: zs.21633_9.sep, s_position: 4.354999999999909, blade_position: 0.06380150000000001, thickness: 6e-05
# Element: zs.21639_0.sep, s_position: 5.474999999999973, blade_position: 0.06212, thickness: 6e-05
# Element: zs.21639_1.sep, s_position: 5.784999999999918, blade_position: 0.0616535, thickness: 6e-05
# Element: zs.21639_2.sep, s_position: 6.094999999999864, blade_position: 0.061187, thickness: 6e-05
# Element: zs.21639_3.sep, s_position: 6.405000000000037, blade_position: 0.060720500000000004, thickness: 6e-05
# Element: zs.21639_4.sep, s_position: 6.714999999999982, blade_position: 0.060254, thickness: 6e-05
# Element: zs.21639_5.sep, s_position: 7.0249999999999275, blade_position: 0.0597875, thickness: 6e-05
# Element: zs.21639_6.sep, s_position: 7.334999999999818, blade_position: 0.059321, thickness: 6e-05
# Element: zs.21639_7.sep, s_position: 7.644999999999991, blade_position: 0.058854500000000004, thickness: 6e-05
# Element: zs.21639_8.sep, s_position: 7.954999999999936, blade_position: 0.058388, thickness: 6e-05
# Element: zs.21639_9.sep, s_position: 8.264999999999882, blade_position: 0.0579215, thickness: 6e-05
# Element: zs.21655_0.sep, s_position: 9.384999999999717, blade_position: 0.05623, thickness: 0.0001
# Element: zs.21655_1.sep, s_position: 9.694999999999663, blade_position: 0.0557635, thickness: 0.0001
# Element: zs.21655_2.sep, s_position: 10.004999999999608, blade_position: 0.055297, thickness: 0.0001
# Element: zs.21655_3.sep, s_position: 10.314999999999781, blade_position: 0.054830500000000004, thickness: 0.0001
# Element: zs.21655_4.sep, s_position: 10.624999999999726, blade_position: 0.054364, thickness: 0.0001
# Element: zs.21655_5.sep, s_position: 10.934999999999672, blade_position: 0.0538975, thickness: 0.0001
# Element: zs.21655_6.sep, s_position: 11.244999999999562, blade_position: 0.053431, thickness: 0.0001
# Element: zs.21655_7.sep, s_position: 11.554999999999735, blade_position: 0.052964500000000005, thickness: 0.0001
# Element: zs.21655_8.sep, s_position: 11.86499999999968, blade_position: 0.052498, thickness: 0.0001
# Element: zs.21655_9.sep, s_position: 12.174999999999626, blade_position: 0.0520315, thickness: 0.0001
# Element: zs.21671_0.sep, s_position: 13.294999999999689, blade_position: 0.05035, thickness: 0.0001
# Element: zs.21671_1.sep, s_position: 13.604999999999634, blade_position: 0.0498835, thickness: 0.0001
# Element: zs.21671_2.sep, s_position: 13.91499999999958, blade_position: 0.049416999999999996, thickness: 0.0001
# Element: zs.21671_3.sep, s_position: 14.224999999999753, blade_position: 0.0489505, thickness: 0.0001
# Element: zs.21671_4.sep, s_position: 14.534999999999698, blade_position: 0.048484, thickness: 0.0001
# Element: zs.21671_5.sep, s_position: 14.844999999999644, blade_position: 0.0480175, thickness: 0.0001
# Element: zs.21671_6.sep, s_position: 15.154999999999534, blade_position: 0.047550999999999996, thickness: 0.0001
# Element: zs.21671_7.sep, s_position: 15.464999999999707, blade_position: 0.0470845, thickness: 0.0001
# Element: zs.21671_8.sep, s_position: 15.774999999999652, blade_position: 0.046618, thickness: 0.0001
# Element: zs.21671_9.sep, s_position: 16.084999999999596, blade_position: 0.0461515, thickness: 0.0001
# Element: zs.21676_0.sep, s_position: 17.20499999999966, blade_position: 0.04446, thickness: 0.0001
# Element: zs.21676_1.sep, s_position: 17.514999999999606, blade_position: 0.0439935, thickness: 0.0001
# Element: zs.21676_2.sep, s_position: 17.82499999999955, blade_position: 0.043526999999999996, thickness: 0.0001
# Element: zs.21676_3.sep, s_position: 18.134999999999724, blade_position: 0.0430605, thickness: 0.0001
# Element: zs.21676_4.sep, s_position: 18.44499999999967, blade_position: 0.042594, thickness: 0.0001
# Element: zs.21676_5.sep, s_position: 18.754999999999615, blade_position: 0.0421275, thickness: 0.0001
# Element: zs.21676_6.sep, s_position: 19.064999999999507, blade_position: 0.041661, thickness: 0.0001
# Element: zs.21676_7.sep, s_position: 19.37499999999968, blade_position: 0.0411945, thickness: 0.0001
# Element: zs.21676_8.sep, s_position: 19.684999999999626, blade_position: 0.040728, thickness: 0.0001
# Element: zs.21676_9.sep, s_position: 19.99499999999957, blade_position: 0.0402615, thickness: 0.0001
# Element: tpst.21760_0.sep, s_position: 43.24269999999944, blade_position: 0.04, thickness: 0.0042
# Element: tpst.21760_1.sep, s_position: 43.48269999999945, blade_position: 0.040106, thickness: 0.0042
# Element: tpst.21760_2.sep, s_position: 43.722699999999456, blade_position: 0.040212, thickness: 0.0042
# Element: tpst.21760_3.sep, s_position: 43.962699999999465, blade_position: 0.040318, thickness: 0.0042
# Element: tpst.21760_4.sep, s_position: 44.202699999999474, blade_position: 0.040424, thickness: 0.0042
# Element: tpst.21760_5.sep, s_position: 44.44269999999948, blade_position: 0.040530000000000004, thickness: 0.0042
# Element: tpst.21760_6.sep, s_position: 44.68269999999949, blade_position: 0.040636, thickness: 0.0042
# Element: tpst.21760_7.sep, s_position: 44.9226999999995, blade_position: 0.040742, thickness: 0.0042
# Element: tpst.21760_8.sep, s_position: 45.16269999999951, blade_position: 0.040848, thickness: 0.0042
# Element: tpst.21760_9.sep, s_position: 45.40269999999952, blade_position: 0.040954000000000004, thickness: 0.0042
# Element: mst.21774_0.sep, s_position: 47.37569999999921, blade_position: 0.04079, thickness: 0.0042
# Element: mst.21774_1.sep, s_position: 47.61569999999922, blade_position: 0.040909, thickness: 0.0042
# Element: mst.21774_2.sep, s_position: 47.85569999999923, blade_position: 0.041028, thickness: 0.0042
# Element: mst.21774_3.sep, s_position: 48.09569999999924, blade_position: 0.041147, thickness: 0.0042
# Element: mst.21774_4.sep, s_position: 48.33569999999925, blade_position: 0.041266, thickness: 0.0042
# Element: mst.21774_5.sep, s_position: 48.5756999999992, blade_position: 0.041385, thickness: 0.0042
# Element: mst.21774_6.sep, s_position: 48.81569999999921, blade_position: 0.041504, thickness: 0.0042
# Element: mst.21774_7.sep, s_position: 49.05569999999922, blade_position: 0.041623, thickness: 0.0042
# Element: mst.21774_8.sep, s_position: 49.29569999999923, blade_position: 0.041742, thickness: 0.0042
# Element: mst.21774_9.sep, s_position: 49.53569999999924, blade_position: 0.041861, thickness: 0.0042
# Element: mst.21779_0.sep, s_position: 50.60969999999902, blade_position: 0.0424, thickness: 0.0042
# Element: mst.21779_1.sep, s_position: 50.84969999999903, blade_position: 0.042519, thickness: 0.0042
# Element: mst.21779_2.sep, s_position: 51.08969999999904, blade_position: 0.042638, thickness: 0.0042
# Element: mst.21779_3.sep, s_position: 51.32969999999905, blade_position: 0.042757, thickness: 0.0042
# Element: mst.21779_4.sep, s_position: 51.56969999999906, blade_position: 0.042876, thickness: 0.0042
# Element: mst.21779_5.sep, s_position: 51.80969999999901, blade_position: 0.042995, thickness: 0.0042
# Element: mst.21779_6.sep, s_position: 52.04969999999902, blade_position: 0.043114, thickness: 0.0042
# Element: mst.21779_7.sep, s_position: 52.28969999999903, blade_position: 0.043233, thickness: 0.0042
# Element: mst.21779_8.sep, s_position: 52.52969999999904, blade_position: 0.043352, thickness: 0.0042
# Element: mst.21779_9.sep, s_position: 52.76969999999905, blade_position: 0.043471, thickness: 0.0042
# Element: mst.21794_0.sep, s_position: 53.84369999999906, blade_position: 0.04401, thickness: 0.0042
# Element: mst.21794_1.sep, s_position: 54.08369999999907, blade_position: 0.044129, thickness: 0.0042
# Element: mst.21794_2.sep, s_position: 54.32369999999908, blade_position: 0.044248, thickness: 0.0042
# Element: mst.21794_3.sep, s_position: 54.56369999999909, blade_position: 0.044367000000000004, thickness: 0.0042
# Element: mst.21794_4.sep, s_position: 54.8036999999991, blade_position: 0.044486, thickness: 0.0042
# Element: mst.21794_5.sep, s_position: 55.04369999999905, blade_position: 0.044605, thickness: 0.0042
# Element: mst.21794_6.sep, s_position: 55.28369999999906, blade_position: 0.044724, thickness: 0.0042
# Element: mst.21794_7.sep, s_position: 55.52369999999907, blade_position: 0.044843, thickness: 0.0042
# Element: mst.21794_8.sep, s_position: 55.763699999999076, blade_position: 0.044962, thickness: 0.0042
# Element: mst.21794_9.sep, s_position: 56.003699999999085, blade_position: 0.045081, thickness: 0.0042
# Element: mse.21832_0.sep, s_position: 64.82839999999884, blade_position: 0.0527, thickness: 0.01725
# Element: mse.21832_1.sep, s_position: 65.0563999999989, blade_position: 0.052597, thickness: 0.01725
# Element: mse.21832_2.sep, s_position: 65.28439999999874, blade_position: 0.052494, thickness: 0.01725
# Element: mse.21832_3.sep, s_position: 65.5123999999988, blade_position: 0.052391, thickness: 0.01725
# Element: mse.21832_4.sep, s_position: 65.74039999999887, blade_position: 0.052288, thickness: 0.01725
# Element: mse.21832_5.sep, s_position: 65.96839999999894, blade_position: 0.052184999999999995, thickness: 0.01725
# Element: mse.21832_6.sep, s_position: 66.19639999999872, blade_position: 0.052081999999999996, thickness: 0.01725
# Element: mse.21832_7.sep, s_position: 66.42439999999878, blade_position: 0.051979, thickness: 0.01725
# Element: mse.21832_8.sep, s_position: 66.65239999999885, blade_position: 0.051876, thickness: 0.01725
# Element: mse.21832_9.sep, s_position: 66.88039999999869, blade_position: 0.051773, thickness: 0.01725
# Element: mse.21837_0.sep, s_position: 68.06239999999865, blade_position: 0.05184, thickness: 0.01725
# Element: mse.21837_1.sep, s_position: 68.29039999999871, blade_position: 0.052028, thickness: 0.01725
# Element: mse.21837_2.sep, s_position: 68.51839999999855, blade_position: 0.052216, thickness: 0.01725
# Element: mse.21837_3.sep, s_position: 68.74639999999862, blade_position: 0.052404, thickness: 0.01725
# Element: mse.21837_4.sep, s_position: 68.97439999999868, blade_position: 0.052592, thickness: 0.01725
# Element: mse.21837_5.sep, s_position: 69.20239999999875, blade_position: 0.052779999999999994, thickness: 0.01725
# Element: mse.21837_6.sep, s_position: 69.43039999999853, blade_position: 0.052967999999999994, thickness: 0.01725
# Element: mse.21837_7.sep, s_position: 69.6583999999986, blade_position: 0.053155999999999995, thickness: 0.01725
# Element: mse.21837_8.sep, s_position: 69.88639999999866, blade_position: 0.053343999999999996, thickness: 0.01725
# Element: mse.21837_9.sep, s_position: 70.1143999999985, blade_position: 0.053531999999999996, thickness: 0.01725
# Element: mse.21852_0.sep, s_position: 71.29639999999846, blade_position: 0.05511, thickness: 0.01725
# Element: mse.21852_1.sep, s_position: 71.52439999999852, blade_position: 0.055588, thickness: 0.01725
# Element: mse.21852_2.sep, s_position: 71.75239999999836, blade_position: 0.056066, thickness: 0.01725
# Element: mse.21852_3.sep, s_position: 71.98039999999843, blade_position: 0.056544, thickness: 0.01725
# Element: mse.21852_4.sep, s_position: 72.20839999999849, blade_position: 0.057021999999999996, thickness: 0.01725
# Element: mse.21852_5.sep, s_position: 72.43639999999856, blade_position: 0.057499999999999996, thickness: 0.01725
# Element: mse.21852_6.sep, s_position: 72.66439999999834, blade_position: 0.057978, thickness: 0.01725
# Element: mse.21852_7.sep, s_position: 72.8923999999984, blade_position: 0.058456, thickness: 0.01725
# Element: mse.21852_8.sep, s_position: 73.12039999999847, blade_position: 0.058934, thickness: 0.01725
# Element: mse.21852_9.sep, s_position: 73.3483999999983, blade_position: 0.059412, thickness: 0.01725
# Element: mse.21857_0.sep, s_position: 74.5303999999985, blade_position: 0.0625, thickness: 0.01725
# Element: mse.21857_1.sep, s_position: 74.75839999999856, blade_position: 0.063269, thickness: 0.01725
# Element: mse.21857_2.sep, s_position: 74.9863999999984, blade_position: 0.064038, thickness: 0.01725
# Element: mse.21857_3.sep, s_position: 75.21439999999846, blade_position: 0.064807, thickness: 0.01725
# Element: mse.21857_4.sep, s_position: 75.44239999999853, blade_position: 0.065576, thickness: 0.01725
# Element: mse.21857_5.sep, s_position: 75.6703999999986, blade_position: 0.066345, thickness: 0.01725
# Element: mse.21857_6.sep, s_position: 75.89839999999838, blade_position: 0.06711400000000001, thickness: 0.01725
# Element: mse.21857_7.sep, s_position: 76.12639999999844, blade_position: 0.067883, thickness: 0.01725
# Element: mse.21857_8.sep, s_position: 76.3543999999985, blade_position: 0.068652, thickness: 0.01725
# Element: mse.21857_9.sep, s_position: 76.58239999999834, blade_position: 0.069421, thickness: 0.01725
# Element: mse.21872_0.sep, s_position: 77.7643999999983, blade_position: 0.074, thickness: 0.01725
# Element: mse.21872_1.sep, s_position: 77.99239999999837, blade_position: 0.07506, thickness: 0.01725
# Element: mse.21872_2.sep, s_position: 78.22039999999821, blade_position: 0.07612, thickness: 0.01725
# Element: mse.21872_3.sep, s_position: 78.44839999999827, blade_position: 0.07718, thickness: 0.01725
# Element: mse.21872_4.sep, s_position: 78.67639999999834, blade_position: 0.07823999999999999, thickness: 0.01725
# Element: mse.21872_5.sep, s_position: 78.9043999999984, blade_position: 0.0793, thickness: 0.01725
# Element: mse.21872_6.sep, s_position: 79.13239999999819, blade_position: 0.08036, thickness: 0.01725
# Element: mse.21872_7.sep, s_position: 79.36039999999825, blade_position: 0.08141999999999999, thickness: 0.01725
# Element: mse.21872_8.sep, s_position: 79.58839999999832, blade_position: 0.08248, thickness: 0.01725
# Element: mse.21872_9.sep, s_position: 79.81639999999815, blade_position: 0.08353999999999999, thickness: 0.01725
# /var/folders/vc/njn3rgb96cq7_32jmcfzppkm0000gn/T/ipykernel_55504/658899991.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='lower right')
